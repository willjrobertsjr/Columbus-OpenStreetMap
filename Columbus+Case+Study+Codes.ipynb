# %% [markdown]
# * Look at tag types (from Iterative Parsing Quiz)

# %%
import xml.etree.ElementTree as ET
import csv
import codecs
import pprint
import re
from collections import defaultdict

OSM_FILE = "Columbus.osm"

def count_tags(filename):
    tags = {}
    for event, element in ET.iterparse(filename):
        if element.tag not in tags.keys():
            tags[element.tag] = 1
        else:
            tags[element.tag] += 1
    
    return tags

print count_tags(OSM_FILE)
# Out:
# {'node': 675741, 'member': 18913, 'nd': 797507, 'tag': 422176, 'bounds': 1, 'note': 1, 'meta': 1, 'relation': 1124, 'way': 75957, 'osm': 1}

# %% [markdown]
# * Look at problem characters (from Tag Types Quiz)

# %%
lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')


def key_type(element, keys): #count for each type of error keys given regex above
    if element.tag == "tag":
        k = element.attrib['k']
        if re.search(lower, k):
            keys['lower'] += 1
        elif re.search(lower_colon, k):
            keys['lower_colon'] += 1
        elif re.search(problemchars, k):
            keys['problemchars'] += 1
        else:
            keys['other'] +=1
        pass
        
    return keys

def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys


keys = process_map(OSM_FILE)
pprint.pprint(keys)
# Out:
# {'lower': 199265, 'lower_colon': 212021, 'other': 10889, 'problemchars': 1}

# %% [markdown]
# * Exploring Users from Exploring Users Quiz

# %%
def get_user(element):
    return


def process_map(filename):
    users = set()
    for _, element in ET.iterparse(filename):
        if element.get('uid'):
            id = element.attrib['uid']
            users.add(id)

    return users

# %% [markdown]
# * Create dictionary of keys and values to see which specifically to audit

# %%
def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag

    Reference:
    http://stackoverflow.com/questions/3095434/inserting-newlines-in-xml-file-generated-via-xml-etree-elementtree-in-python
    """
    context = iter(ET.iterparse(osm_file, events=('start', 'end')))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()

def waynode_kv(osmfile): #add keys to dictionary with each instance of a value
    osm_file = open(osmfile, "r")
    unique_kv = defaultdict(set)
    for i, element in enumerate(get_element(osm_file)):
        if element.tag == "node" or element.tag == "way":                         
            for tag in element.iter("tag"):        
                unique_kv[tag.attrib['k']].add(tag.attrib['v'])    
    print len(unique_kv.keys())  
    return unique_kv

waynode_kv(OSM_FILE)
# Out:
# 481
# defaultdict(set,
#             {'Area': {'brownfield'},
#              'Business': {'CTL Engineering'},
#              'Category': {'Adult Day Care', 'Recycling Center'},
#              'Catering': {'Yes'},
#              'Comments': {'Added for OSU G607 SP2012'},
#              'FIXME': {'Exactly where is the south end of current trackage?',
#               'Is this all Creekside?',
#               'check lanes',
#               'continue?',
#               'detatch from boundary',
#               'is the correct maxspeed 25 mph (40 km/h) or 40 mph?',
#               'name?',
#               'not dual carriageway',
#               'rough alignment',
#               'validate speed limit change location',
#               'validate speed limit is still 65 mph',
#               'verify'},
#              'FIXME:cycleway': {'verify'},
#              'FIXME:name': {'no', 'yes'},
#              'FIXME:ref': {'verify'},
#              'Fax': {'614-478-5824'},
#              'Government': {'State of Ohio - Department of Natural Resources'},
#              'NHS': {'yes'},
#              'Pull_through': {'yes'},
#              'RV': {'yes'},
#              'Truck': {'yes'},
#              'abandoned': {'yes'},
#              'abandoned:amenity': {'cafe', 'restaurant'},
#              'abandoned:cuisine': {'coffee_shop'},
#              'abbr_name': {'11th Ave',
#               '11th St',
#               '15th Ave',
#               '17th Ave',
#               '17th St',
#               '18th St',
#               '2nd Ave',
#               '2nd St',
#               '3rd Ave',
#               '3rd St',
#               '4th St',
#               '5th Ave',
#               '5th St',
#               '6th St',
#               '7th Ave',
#               '9th St',
#               'Ackerman Rd',
#               'Adams Ln',
#               'Africa Rd',
#               'Agler Rd',
#               'Airport Dr',
#               'Alkire Rd',
#               'Alton & Darby Creek Rd',
#               'Alton Darby Creek Rd',
#               'Alum Creek Dr',
#               'Amity Rd',
#               'Anson Dr',
#               'Avery Rd',
#               'Avery-Muirfield Dr',
#               'Azalee Ct',
#               'Baldwin Rd',
#               'Battle Creek Way',
#               'Beach Rd',
#               'Belle St',
#               'Bellow Falls Pl',
#               'Benedict Dr',
#               'Berger Rd',
#               'Berthold Pass Dr',
#               'Bethel Rd',
#               'Big Run South Rd',
#               'Blazer Pkwy',
#               'Bloomington Blvd',
#               'Bow Falls Blvd',
#               'Brand Rd',
#               'Brice Rd',
#               'Britton Pkwy',
#               'Britton Rd',
#               'Broad Meadows Blvd',
#               'Broad St',
#               'Brock Rd',
#               'Brown Rd',
#               'Bryden Rd',
#               'Buckeye Pkwy',
#               'Buena Vista Dr',
#               'Buenos Aires Blvd',
#               'Buttles Ave',
#               'Calypso Cascades Dr',
#               'Campus View Blvd',
#               'Canaan Blvd',
#               'Cannon Dr',
#               'Capital St',
#               'Cardinal Pl',
#               'Cassady Av',
#               'Cassady Ave',
#               'Cedar Rapids Dr',
#               'Cemetery Rd',
#               'Center St',
#               'Central Ave',
#               'Central College Rd',
#               'Champion Ave',
#               'Chapel St',
#               'Chatterton Rd',
#               'Chestnut St',
#               'Chippewa Falls St',
#               'Civic Ctr Dr',
#               'Cleveland Av',
#               'Cleveland Ave',
#               'Clime Rd',
#               'Cole St',
#               'College Ave',
#               'Columbia St',
#               'Columbus St',
#               'Convention Ctr Dr',
#               'Cooke Rd',
#               'Corr Rd',
#               'Cosgray Rd',
#               'Courtright Rd',
#               'Creek Rd',
#               'Cross River Falls Blvd',
#               'Crown Ridge Blvd',
#               'Crystal Falls St',
#               'Darby Creek Dr',
#               'Darby St',
#               'Darlene Pl',
#               'Davidson Rd',
#               'Davis Ave',
#               'Demorest Rd',
#               'Dimension Dr',
#               'Dodridge St',
#               'Dovalon Pl',
#               'Drexel Ave',
#               'Dublin Rd',
#               'Dublin-Granville Rd',
#               'Dukewell Pl',
#               'Duncan St',
#               'E Broad St',
#               'E Main St',
#               'Eiterman Rd',
#               'Elijah Pierce Ave',
#               'Emerald Pkwy',
#               'Feder Rd',
#               'Ferris Rd',
#               'Firehole Falls St',
#               'Fisher Rd',
#               'Fisher Run Ct',
#               'Fishinger Blvd',
#               'Fishinger Rd',
#               'Flint Creek Ave',
#               'Flint Rd',
#               'Frank Rd',
#               'Franklin Park S',
#               'Franklin Park W',
#               'Franklin St',
#               'Frantz Rd',
#               'Frebis Ave',
#               'Front St',
#               'Front Street',
#               'Fulton St',
#               'Gadston Way',
#               'Galveston Dr',
#               'Gantz Rd',
#               'Gardner Rd',
#               'Gary Ganue Dr',
#               'Gateway West Dr',
#               'Gay Rd',
#               'Gay St',
#               'Gaymon Dr',
#               'Gender Rd',
#               'Georgesville Rd',
#               'Georgesville-Wrightsville Rd',
#               'Gift St',
#               'Gilridge Dr',
#               'Glynwater Ln',
#               'Godown Rd',
#               'Golden Cascade Dr',
#               'Goodale Blvd',
#               'Goodale St',
#               'Governors Pl',
#               'Grace St',
#               'Grandview Ave',
#               'Grant Ave',
#               'Grant St',
#               'Granville St',
#               'Greenlawn Ave',
#               'Grener Ave',
#               'Grove City Rd',
#               'Grove St',
#               'Groveport Rd',
#               'Grubb St',
#               'HUMC',
#               'Haenzel Rd',
#               'Hague Av',
#               'Hague Ave',
#               'Hamilton Rd',
#               'Hamlet St',
#               'Hard Rd',
#               'Hardy Pkwy',
#               'Harlem Rd',
#               'Harmon Ave',
#               'Harrisburg Georgesville Rd',
#               'Harrisburg Pk',
#               'Haughn Rd',
#               'Haul Rd',
#               'Havens Corners Rd',
#               'Hayden Rd',
#               'Hayden Run Blvd',
#               'Hayden Run Rd',
#               'Hemlock Edge Dr',
#               'Henderson Rd',
#               'Hickory St',
#               'High Cross Blvd',
#               'High School Dr',
#               'High St',
#               'Hilliard-Rome Rd',
#               'Hocking St',
#               'Holt Rd',
#               'Hoover Rd',
#               'Horizon Dr',
#               'Horseshoe Falls Dr',
#               'Hudson St',
#               'Huntington Park Dr',
#               'Huntley Rd',
#               'Hutchinson Ave;Huntington Park Dr',
#               'Impound Lot Rd',
#               'Indianola Ave',
#               'Industrial Pkwy',
#               'Innis Rd',
#               'Ithaca Dr',
#               'Ivy Crest Ct',
#               'Jack Gibbs Blvd',
#               'Jackson St',
#               'James Rd',
#               'Jasonway Ave',
#               'John Circle Dr',
#               'John Herrick Dr',
#               'Johnson Rd',
#               'Johnstown Rd',
#               'Joneswood Dr',
#               'Joyce Ave',
#               'Karl Rd',
#               'Kelton Ave',
#               'Kenny Rd',
#               'Kerr St',
#               'Kilbourne St',
#               'King Ave',
#               'Kinnear Rd',
#               'Kropp Rd',
#               'Lakefield Ct',
#               'Lakefield Dr',
#               'Lakeview Plaza Blvd',
#               'Lambert Rd',
#               'Lancaster Ave',
#               'Lane Ave',
#               'Lattimer St',
#               'Lazelle Rd E',
#               'Lazelle St',
#               'Leap Rd',
#               'Leonard Ave',
#               'Leonard/5th Ave',
#               'Lester Dr',
#               'Library Park N',
#               'Linworth Rd',
#               'Lithopolis Rd',
#               'Livingston Ave',
#               'Lockbourne Rd',
#               'London Groveport Rd',
#               'Long St',
#               'Ludlow St',
#               'Lukens Rd',
#               'Lyman Dr',
#               'Lynn St',
#               'MLKJ Blvd',
#               'Madison St',
#               'Main St',
#               'Marconi Blvd',
#               'Marion Rd',
#               'McDowell St',
#               'McGuffey Rd',
#               'McKinley Ave',
#               'Mesa Falls St',
#               'Middle Falls St',
#               'Mill St',
#               'Miller Ave',
#               'Mock Rd',
#               'Mooberry St',
#               'Morse Rd',
#               'Mound St',
#               'Mt Vernon Ave',
#               'Muirfield Dr',
#               'Mystic Falls Dr',
#               'N Broadway',
#               'N High St',
#               'N State St',
#               'National Rd',
#               'Nationwide Blvd',
#               'Naughten St',
#               'Neff Rd',
#               'Neil Ave',
#               'Nelson Rd',
#               'New Albany Condit Rd',
#               'New Albany Rd E',
#               'North St',
#               'North Star Rd',
#               'Northwest Pkwy',
#               'Norton Rd',
#               'Norwich St',
#               'Oak St',
#               'Oakland Park Ave',
#               'Ohio Ave',
#               'Old Grener Ave',
#               'Old Haughn Rd',
#               'Old Industrial Pkwy',
#               'Old Kropp Rd',
#               'Old Leonard Ave',
#               'Old Village Rd',
#               'Olde Roberts Rd',
#               'Olentangy River Rd',
#               'Olentangy River Road',
#               'Orders Rd',
#               'Oregon Rd',
#               'PAES',
#               'Park Rd',
#               'Park St',
#               'Parkway Ln',
#               'Parsons Av',
#               'Parsons Ave',
#               'Pearl St',
#               'Perdue Av',
#               'Perdue Ave',
#               'Perimeter Dr',
#               'Pinnacle Club Dr',
#               'Plain City-Dublin Rd',
#               'Pontius Rd',
#               'Portsmouth-Columbus Rd',
#               'Post Rd',
#               'Professional Pkwy',
#               'Pyramid Falls St',
#               'RPAC',
#               'Rainbow Falls St',
#               'Ravenhill Rd',
#               'Reed Rd',
#               'Refugee Rd',
#               'Renner Rd',
#               'Rensch Rd',
#               'Reynoldsburg New Albany Rd',
#               'Rich St',
#               'Rickenbacker Pkwy W',
#               'Riggins Rd',
#               'Rings Rd',
#               'River St',
#               'Riverside Dr',
#               'Roberts Rd',
#               'Rockaway Falls Blvd',
#               'Royal Arch Cascade Dr',
#               'Russell St',
#               'S High St',
#               'S Old State Rd',
#               'S State St',
#               'Sancus Blvd',
#               'Sandusky St',
#               'Sawmill Rd',
#               'Sawyer Rd',
#               'Schrock Rd',
#               'Scioto & Darby Creek Rd;Scioto Darby Creek Rd',
#               'Scioto Blvd',
#               'Scioto Darby Rd',
#               'Second St',
#               'Sefton Park Dr',
#               'Sentinel Falls St',
#               'Shadewater Dr',
#               'Shamrock Blvd',
#               'Shook Rd',
#               'Silver Falls St',
#               'Sinclair Rd',
#               'Smiths Mill Rd',
#               'Smoky Row Rd',
#               'Souder Ave',
#               'Southwest Blvd',
#               'Spring St',
#               'Spruce St',
#               'St Clair Ave',
#               'Staircase Falls Dr',
#               'Starling St',
#               'State St',
#               'Stelzer Rd',
#               'Strawberry Farms Blvd',
#               'Stringtown Rd',
#               'Sturbridge Ct',
#               'Stygler Rd',
#               'Sullivant Ave',
#               'Summit Bend Rd',
#               'Summit St',
#               'Sunbury Rd',
#               'Tanglewood Park Blvd',
#               'Taylor Ave',
#               'Taylor Lane Av',
#               'Tech Center Dr',
#               'Thurman Ave',
#               'Tower Falls Dr',
#               'Town St',
#               'Trabue Rd',
#               'Tremont Rd',
#               'Trueman Blvd',
#               'Tuller Pkwy',
#               'Tuller Rd',
#               'Tuttle Crossing Blvd',
#               'Tuttle Park Pl',
#               'Tuttle Rd',
#               'Twin Falls Dr',
#               'Twin Rivers Dr',
#               'Upper Metro Pl',
#               'Vantage Dr',
#               'Village Pkwy',
#               'Vine St',
#               'W Broad St',
#               'Walkerview Dr',
#               'Wall St',
#               'Walnut St',
#               'Walton Pkwy',
#               'Warren St',
#               'Washington Ave',
#               'Washington Blvd',
#               'Watkins Rd',
#               'Wayne St',
#               'Weber Rd',
#               'Westerville Rd',
#               'White Rd',
#               'Whittier St',
#               'Wilcox Rd',
#               'Wildcat Falls Dr',
#               'Williams Rd',
#               'Wilson Bridge Rd',
#               'Wilson Rd',
#               'Winters Run Rd',
#               'Woerner Temple Rd',
#               'Woody Hayes Dr',
#               'Worthington Galena Rd',
#               'Worthington Woods Blvd'},
#              'access': {'customers',
#               'designated',
#               'destination',
#               'disabled',
#               'no',
#               'permissive',
#               'private',
#               'public',
#               'unknown',
#               'yes'},
#              'addr:city': {'Adamsville',
#               'Alexandria',
#               'Amlin',
#               'Bexley',
#               'Blacklick',
#               'Brice',
#               'Canal Winchester',
#               'Columbus',
#               'Columbus, OH',
#               'Dublin',
#               'Dublin, OH',
#               'Etna Township',
#               'Gahanna',
#               'Galloway',
#               'Grandview',
#               'Grandview Heights',
#               'Grove City',
#               'Groveport',
#               'Hilliard',
#               'Jackson',
#               'Lewis Center',
#               'London',
#               'Marble Cliff',
#               'New Albany',
#               'Obetz',
#               'Pataskala',
#               'Pickerington',
#               'Pickertington',
#               'Plain City',
#               'Powell',
#               'Reynoldsburg',
#               'Reynoldsburh',
#               'Upper Arlington',
#               'West Jefferson',
#               'Westerville',
#               'Whitehall',
#               'Worthington',
#               'columbus',
#               'dublin',
#               'hilliard'},
#              'addr:country': {'US', 'USA'},
#              'addr:county': {'Franklin'},
#              'addr:full': {'1444 Rentra Dr',
#               '1912 SR 256',
#               '235 Diley Road NW, Pickerington, OH 43147',
#               'South Third Street, Suite 210, Columbus, Ohio 43215'},
#              'addr:housename': {'11th Avenue Garage',
#               '12th Avenue Garage',
#               '5454',
#               '5500',
#               '6147927779',
#               '9th Avenue East Garage',
#               '9th Avenue West Garage',
#               'Acaia',
#               "Adriatico's OSU - Columbus",
#               'Alpha Gamma Rho',
#               'Alpha Gamma Sigma',
#               'Aveda',
#               'BP Gas Station',
#               'Blumen Garten',
#               'Boston Stoker',
#               'Box 9, Hangar A-10',
#               'Bridgeway Academy',
#               'Brown Elementary School',
#               "Bruegger's Bagels",
#               'Building 003',
#               'Building 004',
#               'Building 005',
#               'Building 007',
#               'Building 014',
#               'Building 024',
#               'Building 026',
#               'Building 038',
#               'Building 059',
#               'Building 063',
#               'Building 089',
#               'Building 1101',
#               'Building 1103',
#               'Building 1104',
#               'Building 1106',
#               'Building 112',
#               'Building 113',
#               'Building 131',
#               'Building 157',
#               'Building 163',
#               'Building 165',
#               'Building 176',
#               'Building 187',
#               'Building 246',
#               'Building 266',
#               'Building 273',
#               'Building 275',
#               'Building 276',
#               'Building 277',
#               'Building 281',
#               'Building 294',
#               'Building 302',
#               'Building 303',
#               'Building 306',
#               'Building 337',
#               'Building 347',
#               'Building 348',
#               'Building 349',
#               'Building 353',
#               'Building 354',
#               'Building 360',
#               'Building 375',
#               'Building 379',
#               'Building 382',
#               'Building 46',
#               'Building 846',
#               'Building 878',
#               'Building 995',
#               'COSI',
#               'CS Gallery & Events',
#               'CVS Pharmacy',
#               'Calumet Christian School',
#               'Central Ohio Eyecare',
#               'Char Bar',
#               'City of Columbus: Facilities Management',
#               'Coldstone Creamery',
#               'Columbia Gas of Ohio Building',
#               'Columbus Center',
#               'Coughlin Chevrolet',
#               'Credit Union of Ohio',
#               'Dairy Queen Brazier',
#               'Dirty Dungarees',
#               "Donato's Pizza",
#               'Dr. Summit Shah',
#               'Emma Bailey Elementary School',
#               'Etna Towing',
#               'Etna Twp Admin Bldg',
#               'Family Practice Center',
#               'GOCO Food Mart',
#               'Gateway Complex',
#               'Giant Eagle',
#               'Griggs Resivour Boathouse',
#               'Gymboree Play and Music',
#               'Hang Over Easy',
#               'Harrison Apartments',
#               'Haruki East Japanese Sushi Hibachi',
#               'Hilliard Station Sixth Grade School',
#               'Human Resources',
#               'Huntington Bank',
#               'Hurry and Curry',
#               'Immanuel Baptist Church',
#               'Indianola Informal K-8 School',
#               'J W Reason Elementary School',
#               'JPMorgan Chase & Co.',
#               'Joint Public Safety Building',
#               'KOBO',
#               'Kennedy Commons',
#               "Kohl's",
#               'Kroger',
#               'Kroger Marketplace',
#               "Ledo's Lounge",
#               'Lincoln House',
#               'Little Caesars Pizza',
#               'M.A.N. Mappings Services Ince',
#               'Market District - Giant Eagle',
#               'McConnell Heart Hospital',
#               "McDonald's",
#               'Milestones Learning Center',
#               'Morrison Tower',
#               'Morse Road Krogers',
#               'Motorcycle Hall of Fame Museum',
#               'Mudslingers',
#               'Municipal Light Plant',
#               'Neil Avenue Garage',
#               'North Cannon Garage',
#               'North Market',
#               'North Medical Office Building',
#               'Northbank Condos',
#               'Ohio Mulch - Pataskala',
#               'Ohio Stater Mall',
#               'OhioHealth Arthur G.H. Bing, MD Cancer Center',
#               'OhioHealth Child Care Center',
#               'OhioHealth Riverside Methodist Hospital',
#               'One Nationwide Plaza',
#               'Optimus Prosthetics',
#               'Otterbein Gahanna',
#               'Otterbein New Albany Skilled Nursing and Rehab Neighborhood',
#               'PNC Building',
#               'Panera Bread',
#               'Park-Stradley Hall',
#               'Pataskala Bank - Etna',
#               'PharmaForce Inc.',
#               'Phat Wraps',
#               'Phi Gamma Delta',
#               'Phi Kappa Psi',
#               'Pochi Tea Station',
#               "Rally's",
#               'Rhodes State Office Tower',
#               "Rife's Market",
#               'SafeAuto Hospitals Garage',
#               'Sales Development Services Inc.',
#               'Same Day Surgery Center',
#               'Savor Growl',
#               'Schreiner Ace Hardware',
#               'Shell Gas Station',
#               'Siebert Hall',
#               'Silver Horn Center II',
#               'Sonic Drive-In',
#               'South Campus Gateway Garage',
#               'South Cannon Garage',
#               'South Medical Office Building',
#               'Speedway',
#               'Starbucks',
#               'Store #5927',
#               'Studio 35 Cinema & Drafthouse',
#               'Sullivan Centre',
#               'Supply Chain Services',
#               'The Canterbury Apartments',
#               'The Continental Plaza',
#               'The Crest Gastropub',
#               'The Huntington Center',
#               'The Mike Laemmle Team Realty',
#               'The Ohio Union',
#               'The Olive Tree Mediterranean Cafe',
#               'The Residence on Tenth',
#               'The Thirsty Scholar',
#               'The Varsity Club',
#               'The Wellington School',
#               'Thomas Elementary',
#               'Three Nationwide Plaza',
#               'Tinapple Plaza',
#               'University Flower Shop',
#               'Walgreens #13007',
#               'Wexner Medical Center at The Ohio State University',
#               'Wild Ginger Asian Fusion',
#               'William Green Building',
#               'Winking Lizard Tavern',
#               'Worthington',
#               'Younkin Success Center'},
#              'addr:housenumber': {'4020',
#               '655 N',
#               '5985',
#               '345',
#               '346',
#               '340',
#               '3999',
#               '3993',
#               '6151',
#               '6153',
#               '6155',
#               '2311',
#               '5854',
#               '5855',
#               '5856',
#               '5857',
#               '5850',
#               '5851',
#               '5852',
#               '5853',
#               '295',
#               '5858',
#               '5859',
#               '3680',
#               '4655',
#               '274',
#               '275',
#               '276',
#               '2268',
#               '2447',
#               '2445',
#               '7860',
#               '103',
#               '100',
#               '101',
#               '105',
#               '2041',
#               '9323',
#               '9327',
#               '3510',
#               '2680',
#               '6805',
#               '1434',
#               '91',
#               '90',
#               '95',
#               '94',
#               '96',
#               '1623',
#               '1990',
#               '5181',
#               '5401',
#               '5185',
#               '7175',
#               '8838',
#               '2860',
#               '2862',
#               '2864',
#               '1055/1065/1075',
#               '2868',
#               '3016',
#               '550',
#               '1782 ',
#               '1191',
#               '3340',
#               '1197',
#               '1755',
#               '1177',
#               '1175',
#               '8167',
#               '1171',
#               '1170',
#               '6978',
#               '5532',
#               '1284',
#               '1286',
#               '1281',
#               '1280',
#               '1282',
#               '876',
#               '1578',
#               '684',
#               '1570',
#               '680',
#               '1574',
#               '3434',
#               '3435',
#               '627',
#               '8010',
#               '402 Liberty Way',
#               '1371',
#               '1340',
#               '1375',
#               '1374',
#               '400',
#               '1378',
#               '408',
#               '4030',
#               '5991',
#               '5998',
#               '370',
#               '373',
#               '375',
#               '376',
#               '6143',
#               '397',
#               '395',
#               '6780',
#               '6783',
#               '6782',
#               '2300',
#               '2305',
#               '5847',
#               '5846',
#               '5845',
#               '5844',
#               '5843',
#               '5842',
#               '5841',
#               '5840',
#               '5849',
#               '5848',
#               '3746',
#               '3745',
#               '3740',
#               '241',
#               '240',
#               '243',
#               '242',
#               '2451',
#               '2450',
#               '179',
#               '175',
#               '174',
#               '171',
#               '170',
#               '2051',
#               '3699',
#               '2055',
#               '3690',
#               '7980',
#               '3520',
#               '8591',
#               '6814',
#               '3231',
#               '3237',
#               '1618',
#               '3235',
#               '1616',
#               '1617',
#               '1614',
#               '1615',
#               '1613',
#               '1611',
#               '8849',
#               '2873',
#               '2872',
#               '2871',
#               '2870',
#               '2877',
#               '2876',
#               '2875',
#               '2874',
#               '2879',
#               '2878',
#               '800',
#               '5443',
#               '1788',
#               '1140',
#               '1145',
#               '2966',
#               '5500',
#               '1543',
#               '1540',
#               '8711',
#               '767',
#               '12477',
#               '765',
#               '7560',
#               '7447',
#               '5615',
#               '19',
#               '417',
#               '410',
#               '1380',
#               '3825',
#               '2769',
#               '8440',
#               '4280',
#               '7118',
#               '369',
#               '367',
#               '360',
#               '361',
#               '5277',
#               '6774',
#               '6775',
#               '6777',
#               '6770',
#               '6773',
#               '5872',
#               '5873',
#               '5870',
#               '5871',
#               '5877',
#               '5874',
#               '5875',
#               '5879',
#               '2195',
#               '2793',
#               '2199',
#               '250',
#               '251',
#               '257',
#               '2200',
#               '2201',
#               '910-940',
#               '6271',
#               '2424',
#               '2427',
#               '4429',
#               '165',
#               '166',
#               '167',
#               '160',
#               '161',
#               '162',
#               '6355',
#               '4832',
#               '3685',
#               '4520',
#               '6190',
#               '2510',
#               '2735',
#               '5299',
#               '3535',
#               '1810',
#               '1151',
#               '4333',
#               '10501',
#               '10503',
#               '2167',
#               '1609',
#               '1979',
#               '1600',
#               '3220',
#               '1970',
#               '809',
#               '803',
#               '801',
#               '8850',
#               '805',
#               '2848',
#               '2849',
#               '2846',
#               '2847',
#               '2844',
#               '2845',
#               '2842',
#               '2843',
#               '2840',
#               '2841',
#               '5475',
#               '5470',
#               '1776',
#               '1773',
#               '1778',
#               '1550',
#               '8145',
#               '1150',
#               '8146',
#               '5515',
#               '58',
#               '2998',
#               '2999',
#               '3038',
#               '3039',
#               '1556',
#               '3034',
#               '3035',
#               '2992',
#               '2993',
#               '3030',
#               '50',
#               '3032',
#               '3033',
#               '2990',
#               '8701',
#               '8700',
#               '2991',
#               '3036',
#               '6 E',
#               '56',
#               '51',
#               '3031',
#               '5605',
#               '2996',
#               '52',
#               '421',
#               '420',
#               '1393',
#               '1391',
#               '1390',
#               '530',
#               '8450',
#               '6767',
#               '6766',
#               '6765',
#               '4740',
#               '6761',
#               '5869',
#               '5868',
#               '5865',
#               '5864',
#               '5867',
#               '5866',
#               '5861',
#               '5860',
#               '5863',
#               '5862',
#               '2180',
#               '2187',
#               '229',
#               '13515',
#               '222',
#               '220',
#               '2212',
#               '6208',
#               '6690',
#               '150',
#               '152',
#               '155',
#               '2437',
#               '4511',
#               '6186',
#               '2500',
#               '2720',
#               '5047',
#               '1803',
#               '1801',
#               '1800',
#               '3250',
#               '1947',
#               '1944',
#               '1945',
#               '819',
#               '810',
#               '811',
#               '816',
#               '2858',
#               '5183',
#               '2851',
#               '2850',
#               '2853',
#               '2852',
#               '2855',
#               '2854',
#               '2856',
#               '5461',
#               '10202',
#               '1495',
#               '5466',
#               '1700',
#               '1701',
#               '1708',
#               '3200',
#               '1122',
#               '2988',
#               '3029',
#               '3028',
#               '3027',
#               '3026',
#               '3025',
#               '3024',
#               '3023',
#               '2986',
#               '3021',
#               '3020',
#               '525',
#               '520',
#               '521',
#               '1010',
#               '1233',
#               '4197',
#               '13861',
#               '4191',
#               '5676',
#               '2489',
#               '6504',
#               '439',
#               '4675',
#               '8190',
#               '8197',
#               '5707',
#               '5703',
#               '4772',
#               '4770',
#               '4175',
#               '6758',
#               '6759',
#               '6752',
#               '6753',
#               '6750',
#               '6751',
#               '5818',
#               '5819',
#               '5810',
#               '5811',
#               '5813',
#               '5815',
#               '5816',
#               '5817',
#               '3065',
#               '7172',
#               '235',
#               '230',
#               '231',
#               '2223',
#               '1',
#               '5925',
#               '5927',
#               '5920',
#               '5921',
#               '5922',
#               '5923',
#               '5929',
#               '140',
#               '4500',
#               '3401',
#               '121',
#               '2080',
#               '2081',
#               '3342',
#               '2538',
#               '2539',
#               '7952',
#               '7227',
#               '5075',
#               '3799',
#               '2407',
#               '2156',
#               '2403',
#               '2152',
#               '930',
#               '935',
#               '5380',
#               '5383',
#               '5388',
#               '1956',
#               '9700',
#               '9702',
#               '1958',
#               '3249',
#               '3241',
#               '3240',
#               '3246',
#               '821',
#               '1480',
#               '5498',
#               '1485',
#               '1484',
#               '5491',
#               '3300',
#               '797',
#               '1711',
#               '5251',
#               '793',
#               '1716',
#               '1715',
#               '790',
#               '799',
#               '2412',
#               '3650 Reed Road',
#               '1130',
#               '921',
#               '7781',
#               '3018',
#               '3012',
#               '3010',
#               '7140',
#               '511',
#               '515',
#               '1000',
#               '1227',
#               '8500',
#               '1223',
#               '1220',
#               '5661',
#               '5660',
#               '5665',
#               '2882',
#               '2883',
#               '2880',
#               '2881',
#               '2886',
#               '2887',
#               '2884',
#               '2885',
#               '2888',
#               '2889',
#               '2',
#               '1534',
#               '3872',
#               '10',
#               '6400',
#               '15',
#               '14',
#               '17',
#               '16',
#               '8185',
#               '5715',
#               '5712',
#               '7763',
#               '7769',
#               '3900',
#               '3903',
#               '3909',
#               '4765',
#               '6749',
#               '6748',
#               '5809',
#               '5808',
#               '5803',
#               '5802',
#               '5801',
#               '5800',
#               '5807',
#               '5806',
#               '5805',
#               '5804',
#               '201',
#               '200',
#               '203',
#               '209',
#               '1576',
#               '5930',
#               '682',
#               '2185',
#               '2095',
#               '2094',
#               '1307',
#               '2091',
#               '2090',
#               '3656',
#               '3650',
#               '225',
#               '4496',
#               '5067',
#               '5061',
#               '2700',
#               '4408',
#               '1827',
#               '4402',
#               '2144',
#               '4975',
#               '5390',
#               '5394',
#               '5398',
#               '3271',
#               '3069',
#               '833',
#               '830',
#               '835',
#               '839',
#               '3',
#               '9000',
#               '5485',
#               '5480',
#               '787',
#               '781',
#               '782',
#               '1726',
#               '1724',
#               '788',
#               '29',
#               '60',
#               '3004',
#               '62',
#               '3006',
#               '3001',
#               '65',
#               '3002',
#               '3008',
#               '1370',
#               '1581',
#               '1585',
#               '8497',
#               '1031',
#               '500',
#               '631',
#               '634',
#               '635',
#               '636',
#               '637',
#               '638',
#               '6522',
#               '5657',
#               '4371',
#               '8261',
#               '5650',
#               '2898',
#               '2895',
#               '2894',
#               '2896',
#               '2891',
#               '2890',
#               '2893',
#               '2892',
#               '1455',
#               '1456',
#               '1105',
#               '1450',
#               '1451',
#               '1100',
#               '1453',
#               '1458',
#               '4080',
#               '4081',
#               '3868',
#               '4089',
#               '3860',
#               '3864',
#               '7575',
#               '5724',
#               '5725',
#               '7775',
#               '254 S',
#               '6732',
#               '6733',
#               '6736',
#               '4796',
#               '4790',
#               '5836',
#               '5837',
#               '4150',
#               '5835',
#               '5832',
#               '5833',
#               '5830',
#               '5831',
#               '5838',
#               '5839',
#               '216',
#               '215',
#               '213',
#               '210',
#               '211',
#               '219',
#               '5902',
#               '5903',
#               '5900',
#               '5901',
#               '5906',
#               '5907',
#               '5904',
#               '5905',
#               '5908',
#               '5909',
#               '7800',
#               '3480',
#               '8217',
#               '3645',
#               '3640',
#               '2550',
#               '3005',
#               '2556',
#               '6395',
#               '3000',
#               '5019',
#               '67',
#               '2774',
#               '2777',
#               '1858',
#               '1855',
#               '2173',
#               '2178',
#               '6068',
#               '910',
#               '2600',
#               '1420',
#               '2608',
#               '3260',
#               '845',
#               '840',
#               '8895',
#               '7370',
#               '3364',
#               '10250',
#               '9038',
#               '1739',
#               '1738',
#               '1731',
#               '1735',
#               '1736',
#               '753',
#               '750',
#               '757',
#               '755',
#               '759',
#               '758',
#               '1594',
#               '2959',
#               '2954',
#               '2955',
#               '2956',
#               '2957',
#               '2950',
#               '1598',
#               '2952',
#               '2953',
#               '1024',
#               '505',
#               '600',
#               '1200',
#               '1214',
#               '3104',
#               '3105',
#               '3106',
#               '3100',
#               '3103',
#               '1111',
#               '1444',
#               '1443',
#               '1442',
#               '1117',
#               '8679',
#               '4093',
#               '4090',
#               '4099',
#               '5731',
#               '4584',
#               '484',
#               '480',
#               '12410',
#               '6467',
#               '7742',
#               '35005',
#               '7744',
#               '6788',
#               '5300',
#               '3923',
#               '6721',
#               '6720',
#               '8303',
#               '8300',
#               '6729',
#               '4784',
#               '4780',
#               '5821',
#               '5820',
#               '5823',
#               '5822',
#               '5825',
#               '5824',
#               '5827',
#               '5826',
#               '5829',
#               '5828',
#               '4141',
#               '3856',
#               '3850',
#               '3858',
#               '3859',
#               '6094',
#               '5919',
#               '5918',
#               '5915',
#               '5917',
#               '5916',
#               '5910',
#               '199',
#               '195',
#               '194',
#               '197',
#               '196',
#               '191',
#               '190',
#               '3679',
#               '3670',
#               '3677',
#               '2386',
#               '8665',
#               '3580',
#               '10330',
#               '5000',
#               '9151',
#               '3586',
#               '3588',
#               '2761',
#               '1101',
#               '7900',
#               '9480',
#               '902',
#               '4428',
#               '901',
#               '906',
#               '905',
#               '909',
#               '4427',
#               '1845',
#               '4950',
#               '2160',
#               '2162',
#               '9733',
#               '3294',
#               '1900',
#               '3450',
#               '850',
#               '851',
#               '3455',
#               '7001',
#               '7000',
#               '7007',
#               '5220',
#               '8932',
#               '740',
#               '742',
#               '743',
#               '745',
#               '747',
#               '748',
#               '749',
#               '6891',
#               '7174',
#               '7176',
#               '7171',
#               '7170',
#               '2949',
#               '2948',
#               '2947',
#               '2946',
#               '2945',
#               '2944',
#               '2942',
#               '2941',
#               '2940',
#               '1050',
#               '1051',
#               '5355',
#               '5350',
#               '1058',
#               '1697',
#               '1691',
#               '1270',
#               '610',
#               '1276',
#               '615',
#               '8244',
#               '3115',
#               '3110',
#               '1475',
#               '8425',
#               '1300',
#               '1301',
#               '10659',
#               '496',
#               '490',
#               '4221',
#               '4222',
#               '24',
#               '26',
#               '27',
#               '20',
#               '21',
#               '22',
#               '23',
#               '7592',
#               '7757',
#               '7751',
#               '8333',
#               '6716',
#               '6717',
#               '4130',
#               '5692',
#               '3840',
#               '5691',
#               '3844',
#               '3848',
#               '4040',
#               '3664',
#               '3666',
#               '3662',
#               '2280',
#               '2282',
#               '1614B',
#               '4541',
#               '2575',
#               '2375',
#               '3590',
#               '2590',
#               '2593',
#               '1085',
#               '5030',
#               '1877',
#               '1875',
#               '1871',
#               '1878',
#               '971',
#               '4949',
#               '2118',
#               '183',
#               '180',
#               '181',
#               '187',
#               '184',
#               '2110',
#               '2116',
#               '2623',
#               '2620',
#               '4153',
#               '1919',
#               '7350',
#               '9235',
#               '1912',
#               '3282',
#               '3281',
#               '3280',
#               '869',
#               '4154',
#               '3445',
#               '3440',
#               '867',
#               '2024',
#               '880',
#               '885',
#               '889',
#               '888',
#               '67 East',
#               '8923',
#               '775',
#               '777',
#               '776',
#               '771',
#               '770',
#               '773',
#               '779',
#               '77',
#               '75',
#               '73',
#               '3058',
#               '3059',
#               '2972',
#               '3057',
#               '2970',
#               '2971',
#               '2976',
#               '2977',
#               '2974',
#               '2975',
#               '1040',
#               '1046',
#               '1045',
#               '1918',
#               '1681',
#               '1680',
#               '1685',
#               '2982',
#               '4301',
#               '4300',
#               '669',
#               '668',
#               '1263',
#               '664',
#               '662',
#               '1265',
#               '3022',
#               '8787',
#               '5101',
#               '3126',
#               '1468',
#               '1465',
#               '8',
#               '1315',
#               '1311',
#               '1310',
#               '1319',
#               '5750',
#               '5757',
#               '4239',
#               '4235',
#               '4230',
#               '5590',
#               '3949',
#               '318',
#               '310',
#               '8324',
#               '4199',
#               '5680',
#               '6674',
#               '3610',
#               '3612',
#               '3614',
#               '3616',
#               '2564',
#               '2566',
#               '2365',
#               '2364',
#               '2361',
#               '2585',
#               '5025',
#               ...},
#              'addr:interpolation': {'even', 'odd'},
#              'addr:place': {'Kingsdale Center',
#               'Saint Agatha Catholic Church'},
#              'addr:postcode': {'35005',
#               '43001',
#               '43002',
#               '43004',
#               '43015',
#               '43016',
#               '43017',
#               '43026',
#               '43031',
#               '43035',
#               '43054',
#               '43062',
#               '43064',
#               '43065',
#               '43068',
#               '43081',
#               '43082',
#               '43085',
#               '43109',
#               '43110',
#               '43119',
#               '43119-8650-08',
#               '43123',
#               '43125',
#               '4313',
#               '43137',
#               '43140',
#               '43147',
#               '43162',
#               '43201',
#               '43202',
#               '43203',
#               '43204',
#               '43205',
#               '43206',
#               '43207',
#               '43209',
#               '43210',
#               '43211',
#               '43212',
#               '43213',
#               '43214',
#               '43215',
#               '43215-1430',
#               '43216',
#               '43219',
#               '43220',
#               '43220-4800',
#               '43221',
#               '43222',
#               '43223',
#               '43224',
#               '43227',
#               '43228',
#               '43229',
#               '43230',
#               '43231',
#               '43232',
#               '43235',
#               '43240',
#               '43328',
#               '43802',
#               '8765',
#               'OH',
#               'OH 43206',
#               'Ohio'},
#              'addr:state': {'Alabama',
#               'OH',
#               'OH - Ohio',
#               'Oh',
#               'Ohio',
#               'ga',
#               'oh'},
#              'addr:street': {'3rd Street',
#               '8877',
#               '8897',
#               '8906',
#               'Abbey Road',
#               'Abington Road',
#               'Ackerman Road',
#               'Adams Lane',
#               'Airport Drive',
#               'Alkire Rd',
#               'Alkire Road',
#               'Allegheny Avenue',
#               'Alta View Boulevard',
#               'Alum Creek Drive',
#               'Amity Road',
#               'Andover Road',
#               'Annie & John Glenn Avenue',
#               'Arcadia Avenue',
#               'Arlington Avenue',
#               'Auto Mall Dr',
#               'Avery Road',
#               'Azalee Court',
#               u'Baltimore \u2013 Reynoldsburg Road',
#               'Barnett Road',
#               'Baronsmede Court',
#               'Battle Creek Way',
#               'Becket Avenue',
#               'Beech Road Northwest',
#               'Bellow Falls Place',
#               'Bethel Road',
#               'Big Run South Road',
#               'Bilberry Lane',
#               'Billingsley Road',
#               'Binns Boulevard',
#               'Birchton Court',
#               'Blacklick-Eastern Road Northwest',
#               'Blazer Parkway',
#               'Blazer Pkwy',
#               'Bloomington Boulevard',
#               'Boardwalk Street',
#               'Bobcat Way',
#               'Bradenton Avenue',
#               'Brandonway Drive',
#               'Brayford Drive',
#               'Brice Road',
#               'Bridgeway Avenue',
#               'Britton Parkway',
#               'Britton Road',
#               'Broad Meadows Boulevard',
#               'Broad Street Southwest',
#               'Broadway',
#               'Buckland Drive',
#               'Buenos Aires Boulevard',
#               'Burr Avenue',
#               'Busch Boulevard',
#               'Buttles Avenue',
#               'Byers Circle East',
#               'Caine Rd',
#               'Calumet Street',
#               'Cameron Avenue',
#               'Campus Place',
#               'Cannon Drive',
#               'Canoe Drive',
#               'Carmack Road',
#               'Cedar Rapids Drive',
#               'Cemetery Road',
#               'Centerpoint Dr.',
#               'Central College Road',
#               'Chagrin Drive',
#               'Chambers Rd #250',
#               'Channingway Blvd',
#               'Channingway Center Drive',
#               'Chaucer Drive',
#               'Cherry Bottom Road',
#               'Cleveland Avenue',
#               'Clinton Heights Avenue',
#               'Coffman Road',
#               'College Avenue',
#               'College Road North',
# ...
#               'http://www.mamaspastaandbrew.com/',
#               'http://www.manmapping.com',
#               'http://www.marriott.com/hotels/travel/cmhcn-marriott-columbus-university-area/',
#               'http://www.marriott.com/hotels/travel/cmhdb-courtyard-columbus-dublin/',
#               'http://www.marriott.com/hotels/travel/cmhrn-residence-inn-columbus-university-area/',
#               'http://www.marshallsgrandview.com/',
#               'http://www.mattressfirm.com/stores/ohio/columbus/lennox_station.aspx',
#               'http://www.mcdonalds.com/',
#               'http://www.medcareohio.org/',
#               'http://www.metroparks.net/parks-and-trails/blendon-woods/',
#               'http://www.mfacommunities.com/index.php',
#               'http://www.miranovacolumbus.com',
#               'http://www.motorcyclemuseum.org',
#               'http://www.napls.us/Domain/10',
#               'http://www.napls.us/Domain/11',
#               'http://www.napls.us/domain/111',
#               'http://www.napls.us/domain/112',
#               'http://www.napls.us/site/default.aspx?PageID=1',
#               'http://www.nationwidearena.com/',
#               'http://www.newflyers.net',
#               'http://www.northcommunity.org/',
#               'http://www.obetzah.com',
#               'http://www.ohioconcealedcarryinstitute.com/',
#               'http://www.ohiodominican.edu/',
#               'http://www.ohioschoolforthedeaf.org/',
#               'http://www.oldbagofnails.com/',
#               'http://www.olivetreecolumbus.com/',
#               'http://www.onceriddenbikes.com',
#               'http://www.oreillyauto.com/',
#               'http://www.ossb.oh.gov/',
#               'http://www.osuairport.org/44',
#               'http://www.osuflowers.com/',
#               'http://www.otterbein.edu/',
#               'http://www.paradisegarage.com/',
#               'http://www.pcj.edu/',
#               'http://www.peaceumc.org/',
#               'http://www.performancebike.com',
#               'http://www.pickerington.k12.oh.us/school_home.aspx?schoolID=12',
#               'http://www.pickerington.k12.oh.us/school_home.aspx?schoolID=13',
#               'http://www.pickerington.k12.oh.us/school_home.aspx?schoolID=2',
#               'http://www.pistaciavera.com/',
#               'http://www.plain-city.com',
#               'http://www.plain-city.com/public-safety/plain-city-police',
#               'http://www.planetfitness.com/gyms/hilliard-oh-328',
#               'http://www.poynterlawfirm.com',
#               'http://www.prairietownship.org/130/Fire-Department',
#               'http://www.premierallergyohio.com/columbus-allergist/',
#               'http://www.ranchoalegrerestaurante.com/',
#               'http://www.rei.com',
#               'http://www.reschbakery.com/',
#               'http://www.researchalloys.com/',
#               'http://www.ride-home.com/',
#               'http://www.rotolospizza.com',
#               'http://www.sammysdiscountoutlet.com/',
#               'http://www.schmidthaus.com',
#               'http://www.signcityco.com/',
#               'http://www.somedaysbistro.com',
#               'http://www.southeasterndata.com',
#               'http://www.speedway.com',
#               'http://www.spinellisdeli.com/',
#               'http://www.st-agatha.org/',
#               'http://www.st-therese-retreat.org/',
#               'http://www.staufferfamilydental.com',
#               'http://www.stradersbicycleshop.com/',
#               'http://www.swaco.org/',
#               'http://www.tanprousa.com/',
#               'http://www.teejayes.com/',
#               'http://www.telhio.org',
#               'http://www.templeisrael.org/',
#               'http://www.the94thaero.com/',
#               'http://www.thecandlelab.com',
#               'http://www.thecaribbeanspot.com',
#               'http://www.thedkdiner.com/index.html',
#               'http://www.thenorthstarcafe.com/',
#               'http://www.theoldetownetavern.com',
#               'http://www.tiferethisrael.org/',
#               'http://www.timhortons.com/',
#               'http://www.tirediscounters.com',
#               'http://www.towerwireless.com/',
#               'http://www.travelcentersofamerica.com/location-details/ta-london',
#               'http://www.tritechmultisport.com/',
#               'http://www.twinvisions.net/',
#               'http://www.twspromo.com/',
#               'http://www.uspspostoffices.com/oh/plain-city/plain-city',
#               'http://www.velosciencebikeworks.com',
#               'http://www.vitaminshoppe.com/content/en/stores/store_detail.jsp?sn=532',
#               'http://www.vsinsights.com/',
#               'http://www.walgreens.com',
#               'http://www.walgreens.com/',
#               'http://www.westervillebike.com',
#               'http://www.wexarts.org',
#               'http://www.wildgingerhilliard.com/',
#               'http://www.winebistrocolumbus.com/Menu-Locations/Clintonville',
#               'http://www.winkinglizard.com',
#               'http://www.woodsatjosephinum.org',
#               'http://www.worthington.k12.oh.us/Domain/13',
#               'http://www.worthington.k12.oh.us/Domain/14',
#               'http://www.wpcu.coop/',
#               'http://www.xenos.org/',
#               'http://wwwilliams.com/',
#               'http://xenosschools.org/',
#               'http://younkinsuccess.osu.edu/',
#               'https://columbuszoo.org/',
#               'https://dining.osu.edu/dininglocations/convenience-store/',
#               'https://dining.osu.edu/dininglocations/marketplace/',
#               'https://glassaxis.org/',
#               'https://landgrantbrewing.com/',
#               'https://plus.google.com/108566339947235906944/about?gl=us&hl=en',
#               'https://recsports.osu.edu/facilities/recreation-physical-activity-center-rpac',
#               'https://thechiller.com/',
#               'https://wexnermedical.osu.edu/brain-spine-neuro',
#               'https://www.ardentcommunities.com/communities/index.cfm?community=22',
#               'https://www.columbus.gov/recreationandparks/parks/Hard-Road-Park/',
#               'https://www.facebook.com/AmlinOhio43002/',
#               'https://www.facebook.com/pages/Peanut-Shoppe-Columbus/132792170080584',
#               'https://www.facebook.com/pages/Poblanos-Mexican-Restaurant/436695839706600',
#               'https://www.huntington.com',
#               'https://www.huntington.com/',
#               'https://www.lifetimefitness.com/en/clubs/dublin-oh/your-lt.html',
#               'https://www.lifetimefitness.com/en/clubs/easton-oh/your-lt.html',
#               'https://www.lifetimefitness.com/en/clubs/pickerington-oh/your-lt.html',
#               'https://www.lifetimefitness.com/en/clubs/upper-arlington-oh/your-lt.html',
#               'https://www.marcs.com/stores/marcs-columbus-upper-arlington-grocery-store-43220.aspx',
#               'https://www.masjidomarohio.org/',
#               'https://www.myfirstcitybank.com/',
#               'https://www.osc.edu/',
#               'https://www.pandaexpress.com/',
#               'https://www.penzeys.com/',
#               'https://www.stjohnsgc.org/',
#               'https://www.thedailygrowler.com/',
#               'https://www.usavingsbank.com',
#               'https://zoombezibay.columbuszoo.org/',
#               'kroger.com',
#               'mcdonalds.com',
#               'peets.com',
#               'revolcycles.com',
#               'sb-gourmet.com',
#               'shadylanees.ccsoh.us',
#               'tacobell.com',
#               'unioncafe.com',
#               'unos.com',
#               'usps.com',
#               'weilandsgourmetmarket.com/',
#               'www.barcelonacolumbus.com',
#               'www.crownplata.com/dublinoh',
#               'www.curryandhurryindiancarryoutrestaurant.com/',
#               'www.fleetfeetcolumbus.com/',
#               'www.gotonewlife.com',
#               'www.happydragonlivingston.com',
#               'www.houseofjapanohio.com',
#               'www.hugsnheartselc.com',
#               'www.kohls.com',
#               'www.ohiosurgerycenter.com',
#               'www.olivegarden.com',
#               'www.orvis.com',
#               'www.pinnmetalstairs.com',
#               'www.redlobster.com',
#               'www.starbucks.com',
#               'www.theblackwell.com',
#               'www.themikelaemmleteamrealty.com',
#               'www.wendells.net/'},
#              'wetap:photo': {'http://mdcwetap.atwebpages.com/jpg.php?i=petergleick1349115545803.jpg'},
#              'wetap:status': {'working'},
#              'wetland': {'billabong', 'marsh', 'swamp'},
#              'wheelchair': {'limited', 'no', 'yes'},
#              'wheelchair:description': {'No accessible restrooms'},
#              'width': {'-1',
#               '.25',
#               '.3',
#               '.4',
#               '.42',
#               '.5',
#               '.75',
#               '.8',
#               '.9',
#               '1',
#               '1.1',
#               '1.5',
#               '1.6',
#               '1.7',
#               '1.8',
#               '10ft',
#               '12',
#               '2',
#               '3',
#               '3.5',
#               '4',
#               '45.7',
#               '6.096'},
#              'wifi': {'free', 'no', 'yes'},
#              'wikidata': {'Q1007924',
#               'Q1280192',
#               'Q1440940',
#               'Q14716478',
#               'Q14716521',
#               'Q14716552',
#               'Q14716938',
#               'Q16567',
#               'Q166503',
#               'Q16981914',
#               'Q17148464',
#               'Q1924921',
#               'Q2089711',
#               'Q22095339',
#               'Q2233932',
#               'Q2281225',
#               'Q2527311',
#               'Q2902409',
#               'Q3298441',
#               'Q3394047',
#               'Q3520347',
#               'Q3886801',
#               'Q4570194',
#               'Q464092',
#               'Q4908710',
#               'Q5013508',
#               'Q5031040',
#               'Q5035685',
#               'Q5060677',
#               'Q5092',
#               'Q5149993',
#               'Q5150001',
#               'Q5150026',
#               'Q5150027',
#               'Q5150081',
#               'Q5150126',
#               'Q5150169',
#               'Q5310936',
#               'Q5310939',
#               'Q5310961',
#               'Q5471309',
#               'Q5491542',
#               'Q5491740',
#               'Q5595573',
#               'Q5596342',
#               'Q5600506',
#               'Q5611383',
#               'Q5763219',
#               'Q590713',
#               'Q5935366',
#               'Q6093010',
#               'Q6186725',
#               'Q621956',
#               'Q630874',
#               'Q6485346',
#               'Q6506496',
#               'Q6874577',
#               'Q7080808',
#               'Q7080918',
#               'Q7080978',
#               'Q7080981',
#               'Q7081000',
#               'Q7109428',
#               'Q7190837',
#               'Q7278856',
#               'Q7327561',
#               'Q7588876',
#               'Q774694',
#               'Q7763979',
#               'Q783033',
#               'Q7927342',
#               'Q7985358',
#               'Q7988590',
#               'Q7988592',
#               'Q7988594',
#               'Q7989004',
#               'Q7990266',
#               'Q7993527',
#               'Q8016432',
#               'Q8074173',
#               'Q810911',
#               'Q859456',
#               'Q988937'},
#              'wikipedia': {'en:1995 World Marathon Cup',
#               'en:Alum Creek (Ohio)',
#               'en:American Electric Power',
#               'en:Amlin, Ohio',
#               'en:Baltimore, Ohio',
#               'en:Battelle Memorial Institute',
#               'en:Bernlohr Stadium',
#               'en:Big Walnut Creek',
#               'en:Bill Davis Stadium',
#               'en:Bolton Field',
#               'en:COSI Columbus',
#               'en:Canal Winchester High School',
#               'en:Capital University',
#               'en:Central Crossing High School',
#               'en:Chadwick Arboretum',
#               'en:Columbus Academy',
#               'en:Columbus Alternative High School',
#               'en:Columbus College of Art and Design',
#               'en:Columbus Commons',
#               'en:Columbus Crew Stadium',
#               'en:Columbus Motor Speedway',
#               'en:Columbus Museum of Art',
#               'en:Columbus State Community College',
#               'en:Columbus Zoo and Aquarium',
#               'en:Columbus, Ohio',
#               'en:DeVry University',
#               'en:Drake Performance and Event Center',
#               'en:Dublin Jerome High School',
#               'en:Dublin Methodist Hospital',
#               'en:Dublin Scioto High School',
#               'en:East High School (Columbus, Ohio)',
#               'en:Eastmoor Academy (Columbus, Ohio)',
#               'en:Field of Corn',
#               'en:Fort Hayes Metropolitan Education Center',
#               'en:Franklin Heights High School',
#               'en:Franklin Park Conservatory',
#               'en:Franklin University',
#               'en:Gahanna, Ohio',
#               'en:German Village',
#               'en:Grandview Heights High School',
#               'en:Grant Medical Center',
#               'en:Greater Columbus Convention Center',
#               'en:Grove City High School',
#               'en:Grove City, Ohio',
#               'en:Groveport, Ohio',
#               'en:Hilliard City School District (Franklin County, Ohio)',
#               'en:Hilliard Darby High School',
#               'en:Hilliard, Ohio',
#               'en:Hoover Dam (Ohio)',
#               'en:Hyatt Regency Columbus',
#               'en:Italian Village',
#               'en:Jesse Owens Memorial Stadium',
#               'en:Jonathan Alder High School',
#               'en:Lane Avenue Bridge',
#               'en:LeVeque Tower',
#               'en:Linden-McKinley High School',
#               'en:Miranova Place',
#               'en:Mirror Lake (Ohio)',
#               'en:Motorcycle Hall of Fame',
#               'en:Nationwide Arena',
#               "en:Nationwide Children's Hospital",
#               'en:New Albany High School (Ohio)',
#               'en:New Albany-Plain Local School District',
#               'en:Ohio Dominican University',
#               'en:Ohio School for the Deaf',
#               'en:Ohio Stadium',
#               'en:Ohio State Highway Patrol',
#               'en:Ohio State School for the Blind',
#               'en:Ohio State University Airport',
#               'en:Ohio State University Wexner Medical Center',
#               'en:Ohio Statehouse',
#               'en:Ohio Supercomputer Center',
#               'en:Ohio Theatre (Columbus, Ohio)',
#               'en:Ohio Union',
#               'en:Otterbein University',
#               'en:Panda Express',
#               'en:Pickerington High School North',
#               'en:Polaris Fashion Place',
#               'en:Pontifical College Josephinum',
#               'en:Raccoon Creek (Ohio)',
#               'en:Reynoldsburg, Ohio',
#               'en:Richard M. Ross Heart Hospital',
#               'en:Scioto River',
#               'en:St. John Arena',
#               'en:The Columbus Dispatch',
#               'en:The James Cancer Hospital',
#               'en:The Short North',
#               'en:The Towers (Ohio State)',
#               'en:Upper Arlington, Ohio',
#               'en:Value City Arena',
#               'en:Victorian Village',
#               'en:West High School (Columbus, Ohio)',
#               'en:Westerville Central High School',
#               'en:Westerville North High School',
#               'en:Westerville South High School',
#               'en:Westerville, Ohio',
#               'en:Westland High School',
#               'en:Westland Mall (Columbus)',
#               'en:Wexner Center for the Arts',
#               'en:Whetstone High School (Columbus, Ohio)',
#               'en:William Oxley Thompson Memorial Library',
#               'en:Xenos Christian Fellowship',
#               'en:Zoombezi Bay'},
#              'wood': {'deciduous'},
#              'youtube': {'http://www.youtube.com/watch?v=wqjOjNvSNt0'}})

# %% [markdown]
# * Collect last word of addresses to audit street type (from Improving Street Names Quiz)

# %%
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

street_expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons"]

def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in street_expected:
            street_types[street_type].add(street_name)

def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")

def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    osm_file.close()
    return street_types

audit(OSM_FILE)
# Out:
# defaultdict(set,
#             {'101': {'E Dublin Granville Rd #101'},
#              '105': {'Mill St Suite 105'},
#              '250': {'Chambers Rd #250'},
#              '2D': {'Copeland Mill Rd #2D'},
#              '320': {'W Old Wilson Bridge Rd #320'},
#              '8877': {'8877'},
#              '8897': {'8897'},
#              'Ave': {'N Cassady Ave'},
#              'Blvd': {'Channingway Blvd'},
#              'Broadway': {'Broadway'},
#              'Center': {'Easton Town Center',
#               'Mc Naughten Center',
#               'Tremont Center'},
#              'Circle': {'Ellington Circle',
#               'Gateway Circle',
#               'Parkcenter Circle'},
#              'Crossing': {'Morse Crossing', 'Red Hook Crossing'},
#              'Dr': {'Auto Mall Dr',
#               'Humphries Dr',
#               'Rentra Dr',
#               'Wake Dr',
#               'Westpoint Plaza Dr',
#               'Westpointe Plaza Dr'},
#              'Dr.': {'Centerpoint Dr.'},
#              'East': {'Byers Circle East',
#               'Easton Loop East',
#               'New Albany Road East',
#               'The Strand East'},
#              'Gateway': {'International Gateway'},
#              'Loop': {'Nemain Loop'},
#              'Main': {'College and Main'},
#              'N': {'Coventry Woods Drive N'},
#              'North': {'College Road North',
#               'Freeway Drive North',
#               'Hill Road North',
#               'Metro Place North'},
#              'Northwest': {'Beech Road Northwest',
#               'Blacklick-Eastern Road Northwest'},
#              'Oval': {"Murphy's Oval"},
#              'Park': {'Taylor Park'},
#              'Pike': {'Columbus Pike', 'Jackson Pike', 'Winchester Pike'},
#              'Pkwy': {'Blazer Pkwy'},
#              'Plaza': {'Nationwide Plaza', 'Riverside Plaza'},
#              'Rd': {'Alkire Rd',
#               'Caine Rd',
#               'Courtright Rd',
#               'Edington Rd',
#               'Fodor Rd',
#               'Hilliard-Rome Rd',
#               'Liberty Commons Rd',
#               'Norton Rd',
#               'Roberts Rd',
#               'S Hamilton Rd',
#               'Stringtown Rd'},
#              'Rd.': {'E. Dublin Granville Rd.'},
#              'S': {'Weaver Court S'},
#              'SE': {'Lilly Chapel Opossum Rd SE'},
#              'SW': {'Hazelton-Etna Rd SW', 'National Rd SW'},
#              'South': {'Green Pointe Drive South',
#               'Hill Road South',
#               'Metro Place South'},
#              'Southwest': {'Broad Street Southwest',
#               'Columbia Road Southwest',
#               'Hazelton-Etna Road Southwest',
#               'National Road Southwest',
#               'Refugee Road Southwest'},
#              'St': {'E Broad St',
#               'Hazelton St',
#               'Market St',
#               'S High St',
#               'W Pearl St'},
#              'St.': {'N. High St.'},
#              'Station': {'Easton Station'},
#              'Strand': {'The Strand'},
#              'Way': {'Battle Creek Way',
#               'Bobcat Way',
#               'Emswiler Way',
#               'Gadston Way',
#               'Ikea Way',
#               'Liberation Way',
#               'Liberty Way',
#               'Little Turtle Way',
#               'Stockton Trail Way',
#               'Townsfair Way'},
#              'West': {'County Line Road West',
#               'Easton Loop West',
#               'New Albany Road West',
#               'The Strand West'}})

# %% [markdown]
# * Create dictionary and replace faulty street names

# %%
streetmapping = { "St": "Street",
            "St.": "Street",
            "Ave": "Avenue",
            "Rd.": "Road",
            "Rd": "Road",
            "Blvd": "Boulevard",
            "Dr": "Drive",
            "Dr.": "Drive",
            "S": "South",
            "SE": "Southeast",
            "SW": "Southwest",
            "N": "North",
            "NW": "Northwest",
            "NE": "Northeast",
            "Pkwy": "Parkway",
            "Rd 101": "Road",
            "St Suite 105": "Street",
            "Rd 250": "Road",
            "Rd 2D": "Road",
            "Rd #320": "Road",
            "8877": "Bad Address",
            "8897": " Bad Address"
            }

def update_name_street(name, streetmapping):
    if name == "E Dublin Granville Rd #101":
        name = "E Dublin Granville Road"
    elif name == "Mill St Suite 105":
        name = "Mill Street"
    elif name == "Chambers Rd #250":
        name = "Chambers Road"
    elif name == "Copeland Mill Rd #2D":
        name = "Copeland Mill Road"
    elif name == "W Old Wilson Bridge Rd #320":
        name = "W Old Wilson Bridge Road"
    
    else: 
        m = street_type_re.search(name) #find if street type in above dictionary
        street_type = m.group()
        if street_type in streetmapping.keys():
            name = re.sub(m.group(), streetmapping[m.group()],name)
    return name

for event, element in ET.iterparse(OSM_FILE, events=("start",)):
    if element.tag == "node" or element.tag == "way":
        for tag in element.iter("tag"):
            if tag.attrib['k'] == "addr:street":
                tag.attrib['v'] = update_name_street(tag.attrib['v'], streetmapping)

# %% [markdown]
# * Create dictionary of all zip code values

# %%
def is_zip_code(elem):
    return (elem.attrib['k'] == "addr:postcode")

def audit_zips(osmfile):

    osm_file = open(osmfile, "r")
    zip_codes = {}
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_zip_code(tag):                    
                        if tag.attrib['v'] not in zip_codes:
                            zip_codes[tag.attrib['v']] = 1
                        else:
                            zip_codes[tag.attrib['v']] += 1
    return zip_codes

audit_zips('Columbus.osm')
# Out:
# {'35005': 1,
#  '43001': 1,
#  '43002': 1,
#  '43004': 13,
#  '43015': 1,
#  '43016': 27,
#  '43017': 311,
#  '43026': 86,
#  '43031': 1,
#  '43035': 5,
#  '43054': 12,
#  '43062': 43,
#  '43064': 5,
#  '43065': 3,
#  '43068': 25,
#  '43081': 8,
#  '43082': 7,
#  '43085': 18,
#  '43109': 1,
#  '43110': 2,
#  '43119': 26,
#  '43119-8650-08': 1,
#  '43123': 18,
#  '43125': 5,
#  '4313': 1,
#  '43137': 1,
#  '43140': 2,
#  '43147': 56,
#  '43162': 4,
#  '43201': 66,
#  '43202': 48,
#  '43203': 3,
#  '43204': 11,
#  '43205': 10,
#  '43206': 17,
#  '43207': 16,
#  '43209': 24,
#  '43210': 88,
#  '43211': 4,
#  '43212': 76,
#  '43213': 11,
#  '43214': 46,
#  '43215': 78,
#  '43215-1430': 1,
#  '43216': 1,
#  '43219': 50,
#  '43220': 9,
#  '43220-4800': 1,
#  '43221': 110,
#  '43222': 3,
#  '43223': 2,
#  '43224': 16,
#  '43227': 7,
#  '43228': 30,
#  '43229': 15,
#  '43230': 13,
#  '43231': 17,
#  '43232': 5,
#  '43235': 77,
#  '43240': 16,
#  '43328': 1,
#  '43802': 1,
#  '8765': 1,
#  'OH': 1,
#  'OH 43206': 1,
#  'Ohio': 1}

# %% [markdown]
# * Replace faulty zip codes

# %%
def update_zips(name):
    if len(name) < 5:
        print name, 'updated to:'
        name = "Bad Zip"
        print name
        return name
    elif len(name) > 5: #take only first 5 numbers of zip
        print name, 'updated to:'
        if re.search('[0-9]{5}', name):
            updated_name = re.findall('[0-9]{5}', name)
            name = updated_name[0]
            print name
            return name
    
    else:
        return name
       
for event, element in ET.iterparse(OSM_FILE, events=("start",)):
    if element.tag == "node" or element.tag == "way":
        for tag in element.iter("tag"):
            if tag.attrib['k'] == "addr:postcode":
                tag.attrib['v'] = update_zips(tag.attrib['v'])
# Out:
# 43220-4800 updated to:
# 43220
# 8765 updated to:
# Bad Zip
# 4313 updated to:
# Bad Zip
# 43215-1430 updated to:
# 43215
# OH 43206 updated to:
# 43206
# 43119-8650-08 updated to:
# 43119
# Ohio updated to:
# Bad Zip
# OH updated to:
# Bad Zip

# %% [markdown]
# * Create dictionary of all city values

# %%
def is_city(elem):
    return (elem.attrib['k'] == "addr:city")

def audit_city(osmfile):

    osm_file = open(osmfile, "r")
    cities = {}
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_city(tag):
                    if tag.attrib['v'] not in cities:
                        cities[tag.attrib['v']] = 1
                    else:
                        cities[tag.attrib['v']] += 1
    return cities

audit_city(OSM_FILE)
# Out:
# {'Adamsville': 1,
#  'Alexandria': 1,
#  'Amlin': 1,
#  'Bexley': 12,
#  'Blacklick': 11,
#  'Brice': 1,
#  'Canal Winchester': 3,
#  'Columbus': 782,
#  'Columbus, OH': 4,
#  'Dublin': 306,
#  'Dublin, OH': 15,
#  'Etna Township': 1,
#  'Gahanna': 7,
#  'Galloway': 28,
#  'Grandview': 9,
#  'Grandview Heights': 6,
#  'Grove City': 18,
#  'Groveport': 5,
#  'Hilliard': 80,
#  'Jackson': 1,
#  'Lewis Center': 17,
#  'London': 2,
#  'Marble Cliff': 1,
#  'New Albany': 21,
#  'Obetz': 4,
#  'Pataskala': 22,
#  'Pickerington': 56,
#  'Pickertington': 1,
#  'Plain City': 6,
#  'Powell': 2,
#  'Reynoldsburg': 26,
#  'Reynoldsburh': 1,
#  'Upper Arlington': 98,
#  'West Jefferson': 3,
#  'Westerville': 11,
#  'Whitehall': 1,
#  'Worthington': 21,
#  'columbus': 7,
#  'dublin': 1,
#  'hilliard': 2}

# %% [markdown]
# * Replace faulty city names

# %%
citymapping = { "Columbus, OH": "Columbus",
                "Dublin, OH": "Dublin",
                "Reynoldsburh": "Reynoldsburg",
                "Pickertington": "Pickerington"
            }
                
def update_name_city(name, citymapping):
    if name in citymapping:
        print name, "updated to:"
        name = citymapping[name] 
        if name.islower():
            name = name.capitalize()
        print name
        return name

    else:
        if name.islower():
            name = name.capitalize()
        return name

for event, element in ET.iterparse(OSM_FILE, events=("start",)):
    if element.tag == "node" or element.tag == "way":
        for tag in element.iter("tag"):
            if tag.attrib['k'] == "addr:city":
                tag.attrib['v'] = update_name_city(tag.attrib['v'], citymapping)
# Out:
# Columbus, OH updated to:
# Columbus
# Columbus, OH updated to:
# Columbus
# Pickertington updated to:
# Pickerington
# Reynoldsburh updated to:
# Reynoldsburg
# Dublin, OH updated to:
# Dublin
# Dublin, OH updated to:
# Dublin
# Dublin, OH updated to:
# Dublin
# Dublin, OH updated to:
# Dublin
# Dublin, OH updated to:
# Dublin
# Dublin, OH updated to:
# Dublin
# Dublin, OH updated to:
# Dublin
# Dublin, OH updated to:
# Dublin
# Columbus, OH updated to:
# Columbus
# Columbus, OH updated to:
# Columbus
# Dublin, OH updated to:
# Dublin
# Dublin, OH updated to:
# Dublin
# Dublin, OH updated to:
# Dublin
# Dublin, OH updated to:
# Dublin
# Dublin, OH updated to:
# Dublin
# Dublin, OH updated to:
# Dublin
# Dublin, OH updated to:
# Dublin

# %% [markdown]
# * Create dictionary of denominations

# %%
def is_church(elem):
    return (elem.attrib['k'] == "denomination")

def audit_church(osmfile):

    osm_file = open(osmfile, "r")
    churches = {}
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_church(tag):
                        if tag.attrib['v'] not in churches:
                            churches[tag.attrib['v']] = 1
                        else:
                            churches[tag.attrib['v']] += 1
                        
    return churches

audit_church(OSM_FILE)
# Out:
# {'Baptist': 1,
#  'baptist': 129,
#  'brethren': 1,
#  'catholic': 22,
#  'evangelical': 1,
#  'jehovahs_witness': 2,
#  'lutheran': 41,
#  'messianic_jewish': 2,
#  'methodist': 54,
#  'mormon': 2,
#  'nazarene': 1,
#  'orthodox': 1,
#  'pentecostal': 10,
#  'presbyterian': 18,
#  'protestant': 2,
#  'roman_catholic': 9,
#  'salvation_army': 1,
#  'united_church_of_christ': 1,
#  'united_methodist': 2,
#  'united_methodist;methodist': 1}

# %% [markdown]
# * Replace faulty denomination names

# %%
denommapping = { "united_methodist;methodist": "methodist",
                 "united_methodist": "methodist"
            }

def first_lower(s):
    return s[0].lower() + s[1:]                 

def update_name_denom(name, denommapping):
    if name.istitle():
        print name, 'updated to:'
        name = name.lower()
        print name
        return name
    elif name in denommapping:
        print name, "updated to:"
        name = denommapping[name]
        print name
        return name

    else:
        return name

for event, element in ET.iterparse(OSM_FILE, events=("start",)):
    if element.tag == "node" or element.tag == "way":
        for tag in element.iter("tag"):
            if tag.attrib['k'] == "denomination":
                tag.attrib['v'] = update_name_denom(tag.attrib['v'], denommapping)
# Out:
# Baptist updated to:
# baptist
# united_methodist updated to:
# methodist
# united_methodist;methodist updated to:
# methodist
# united_methodist updated to:
# methodist

# %% [markdown]
# * Create dictionary of sport values

# %%
def is_sport(elem):
    return (elem.attrib['k'] == "sport")

def audit_sports(osmfile):

    osm_file = open(osmfile, "r")
    sports = {}
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_sport(tag):
                    if tag.attrib['v'] not in sports:
                        sports[tag.attrib['v']] = 1
                    else:
                        sports[tag.attrib['v']] += 1
    return sports

audit_sports(OSM_FILE)
# Out:
# {'american_football': 63,
#  'athletics': 2,
#  'baseball': 307,
#  'basketball': 94,
#  'beachvolleyball': 5,
#  'crossfit': 2,
#  'disc_golf': 1,
#  'equestrian': 1,
#  'fitness': 2,
#  'football': 6,
#  'golf': 43,
#  'hockey': 1,
#  'horseshoes': 1,
#  'ice_hockey': 1,
#  'karting': 2,
#  'lacrosse': 1,
#  'martial_arts': 1,
#  'motor': 5,
#  'multi': 4,
#  'racquet': 2,
#  'rock_climbing_wall': 1,
#  'running': 11,
#  'skateboard': 4,
#  'soccer': 98,
#  'soccer,_crossfit': 1,
#  'softball': 16,
#  'swimming': 39,
#  'tennis': 200,
#  'volleyball': 12}

# %% [markdown]
# * Replace faulty sport values

# %%
sportsmapping = { "multi": "athletics",
                  "beachvolleyball": "volleyball",
                  "football": "american_football",
                  "ice_hockey": "hockey",
                  "karting": "motor",
                  "soccer,_crossfit": "soccer",
            }               

def update_name_sport(name, sportsmapping):
    if name in sportsmapping:
        print name, "updated to:"
        name = sportsmapping[name]
        print name
        return name

    else:
        return name

for event, element in ET.iterparse(OSM_FILE, events=("start",)):
    if element.tag == "node" or element.tag == "way":
        for tag in element.iter("tag"):
            if tag.attrib['k'] == "sport":
                tag.attrib['v'] = update_name_sport(tag.attrib['v'], sportsmapping)
# Out:
# multi updated to:
# athletics
# soccer,_crossfit updated to:
# soccer
# ice_hockey updated to:
# hockey
# football updated to:
# american_football
# football updated to:
# american_football
# football updated to:
# american_football
# multi updated to:
# athletics
# football updated to:
# american_football
# football updated to:
# american_football
# beachvolleyball updated to:
# volleyball
# football updated to:
# american_football
# karting updated to:
# motor
# karting updated to:
# motor
# beachvolleyball updated to:
# volleyball
# beachvolleyball updated to:
# volleyball
# beachvolleyball updated to:
# volleyball
# beachvolleyball updated to:
# volleyball
# multi updated to:
# athletics
# multi updated to:
# athletics

# %% [markdown]
# * Create dictionary of cuisine values

# %%
def is_cuisine(elem):
    return (elem.attrib['k'] == "cuisine")

def audit_cuisine(osmfile):

    osm_file = open(osmfile, "r")
    cuisines = {}
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_cuisine(tag):
                        if tag.attrib['v'] not in cuisines:
                            cuisines[tag.attrib['v']] = 1
                        else:
                            cuisines[tag.attrib['v']] += 1
                        
    return cuisines

audit_cuisine(OSM_FILE)
# Out:
# {'American;Mexican': 1,
#  'Asian': 1,
#  'Asian_Fusion': 1,
#  'Bar': 1,
#  'Burrito,_Taco, Salad, Chips': 1,
#  'Chinese': 1,
#  'Deli': 1,
#  'Ice_Cream': 1,
#  'Ice_cream': 2,
#  'Italian': 1,
#  'Japanese_Sushi_Hibachi': 1,
#  'Korean': 1,
#  'Lebanese-American food': 1,
#  'Lebanese_/_Mideastern': 1,
#  'Pasta': 1,
#  'Polynesian': 1,
#  'Steak': 1,
#  'Steakhouse_chain': 1,
#  'Vegan': 1,
#  'Vietnamese': 1,
#  'Vietnamese,_Cambodian': 1,
#  'american': 30,
#  'american_french': 1,
#  'asian': 16,
#  'australian': 1,
#  'bagel': 1,
#  'barbecue': 4,
#  'bavarian;ice_cream': 1,
#  'beer;wings': 1,
#  'breakfast': 3,
#  'buffet': 1,
#  'burger': 75,
#  'burger,_shakes': 1,
#  'caribbean': 1,
#  'chicken': 14,
#  'chinese': 22,
#  'chinese;vietnamese': 1,
#  'coffee_shop': 30,
#  'dessert': 1,
#  'diner': 2,
#  'donut': 2,
#  'donuts': 2,
#  'french': 4,
#  'fusion': 1,
#  'fusion;coffee': 1,
#  'german': 3,
#  'greek': 9,
#  'hawaiian': 1,
#  'home_cooking': 2,
#  'ice_cream': 9,
#  'ice_cream,_frozen_yogurt': 1,
#  'indian': 7,
#  'international': 3,
#  'italian': 26,
#  'italian._pizza,_bbq,_regional': 1,
#  'japanese': 8,
#  'japanese_steakhouse': 1,
#  'juice': 1,
#  'mediterranean': 2,
#  'mexican': 54,
#  'middle_eastern': 2,
#  'nuts;candy': 1,
#  'pasta': 1,
#  'pizza': 48,
#  'regional': 8,
#  'sandwich': 34,
#  'seafood': 3,
#  'smoothies': 1,
#  'spanish': 1,
#  'subs': 2,
#  'sushi': 5,
#  'thai': 1,
#  'turkish': 1,
#  'vietnamese': 1,
#  'wings': 3,
#  'yogurt': 1}

# %% [markdown]
# * Replace faulty cuisine values

# %%
cuisinemapping = { "American;Mexican": "mexican",
                   "Vietnamese,_Cambodian": "vietnamese",
                   "bavarian;ice_cream": "ice_cream",
                   "Asian_Fusion": "asian",
                   "Burrito,_Taco, Salad, Chips": "mexican",
                   "Ice_Cream": "ice_cream",
                   "Deli": "sandwich",
                   "Japanese_Sushi_Hibachi": "japanese",
                   "sushi": "japanese",
                   "japanese_steakhouse": "japanese",
                   "Lebanese-American food": "lebanese",
                   "Lebanese_/_Mideastern": "lebanese",
                   "Pasta": "italian",
                   "pasta": "italian",
                   "Steakhouse_chain": "steak",
                   "american_french": "french",
                   "beer;wings": "wings",
                   "bagel": "breakfast",
                   "burger,_shakes": "burger",
                   "chinese;vietnamese": "chinese",
                   "donut": "breakfast",
                   "donuts": "breakfast",
                   "fusion;coffee": "coffee_shop",
                   "home_cooking": "american",
                   "ice_cream,_frozen_yogurt": "ice_cream",
                   "italian._pizza,_bbq,_regional": "italian",
                   "subs": "sandwich"
            }

               

def update_name_cuisine(name, cuisinemapping):
    if name in cuisinemapping:
        print name, 'updated to:'
        name = cuisinemapping[name]
        print name
        return name

    else:
        return first_lower(name)

for event, element in ET.iterparse(OSM_FILE, events=("start",)):
    if element.tag == "node" or element.tag == "way":
        for tag in element.iter("tag"):
            if tag.attrib['k'] == "cuisine":
                tag.attrib['v'] = update_name_cuisine(tag.attrib['v'], cuisinemapping)
# Out:
# sushi updated to:
# japanese
# beer;wings updated to:
# wings
# Deli updated to:
# sandwich
# japanese_steakhouse updated to:
# japanese
# bagel updated to:
# breakfast
# Japanese_Sushi_Hibachi updated to:
# japanese
# Burrito,_Taco, Salad, Chips updated to:
# mexican
# Vietnamese,_Cambodian updated to:
# vietnamese
# subs updated to:
# sandwich
# donuts updated to:
# breakfast
# Asian_Fusion updated to:
# asian
# ice_cream,_frozen_yogurt updated to:
# ice_cream
# burger,_shakes updated to:
# burger
# subs updated to:
# sandwich
# Pasta updated to:
# italian
# home_cooking updated to:
# american
# sushi updated to:
# japanese
# home_cooking updated to:
# american
# pasta updated to:
# italian
# Lebanese-American food updated to:
# lebanese
# sushi updated to:
# japanese
# bavarian;ice_cream updated to:
# ice_cream
# Lebanese_/_Mideastern updated to:
# lebanese
# fusion;coffee updated to:
# coffee_shop
# chinese;vietnamese updated to:
# chinese
# American;Mexican updated to:
# mexican
# Ice_Cream updated to:
# ice_cream
# sushi updated to:
# japanese
# italian._pizza,_bbq,_regional updated to:
# italian
# sushi updated to:
# japanese
# american_french updated to:
# french
# Steakhouse_chain updated to:
# steak
# donut updated to:
# breakfast
# donut updated to:
# breakfast
# donuts updated to:
# breakfast

# %% [markdown]
# * Create dictionary of maxspeed values

# %%
def is_speed(elem):
    return (elem.attrib['k'] == "maxspeed")

def audit_speeds(osmfile):

    osm_file = open(osmfile, "r")
    speeds = {}
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_speed(tag):
                        if tag.attrib['v'] not in speeds:
                            speeds[tag.attrib['v']] = 1
                        else:
                            speeds[tag.attrib['v']] += 1
                        
    return speeds



audit_speeds(OSM_FILE)
# Out:
# {'10 mph': 20,
#  '105': 71,
#  '129870342181342860 mph': 1,
#  '15 mph': 18,
#  '20 mph': 14,
#  '25': 6,
#  '25 mph': 238,
#  '30 mph': 1,
#  '35 mph': 173,
#  '40': 1,
#  '40 mph': 44,
#  '45': 1,
#  '45 mph': 162,
#  '50 mph': 30,
#  '55 mph': 313,
#  '56': 4,
#  '60 mph': 16,
#  '64': 2,
#  '65 mph': 621,
#  '70': 1,
#  '70 mph': 30,
#  '72': 21,
#  '89': 15}

# %% [markdown]
# * Replace faulty maxspeed values

# %%
OSM_FILE = "Columbus.osm"

def update_name_maxspeed(name): 
    if len(name) > 7:   #remove blatantly bad speed limit 
        name = "Bad Speed"
        return name
    if 'mph' in name:
        return name
    else:
        print name, 'updated to:'  #make uniform by ensuring mph at end
        name = name.strip() + ' mph'
        print name
        return name

for event, element in ET.iterparse(OSM_FILE, events=("start",)):
    if element.tag == "node" or element.tag == "way":
        for tag in element.iter("tag"):
            if tag.attrib['k'] == "maxspeed" and len(tag.attrib['v']) > 7:
                continue
            else:
                if tag.attrib['k'] == "maxspeed":
                    tag.attrib['v'] = update_name_maxspeed(tag.attrib['v'])
# Out:
# 56 updated to:
# 56 mph
# 89 updated to:
# 89 mph
# 40 updated to:
# 40 mph
# 89 updated to:
# 89 mph
# 89 updated to:
# 89 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 25 updated to:
# 25 mph
# 45 updated to:
# 45 mph
# 70 updated to:
# 70 mph
# 25 updated to:
# 25 mph
# 89 updated to:
# 89 mph
# 56 updated to:
# 56 mph
# 25 updated to:
# 25 mph
# 89 updated to:
# 89 mph
# 105 updated to:
# 105 mph
# 64 updated to:
# 64 mph
# 64 updated to:
# 64 mph
# 105 updated to:
# 105 mph
# 72 updated to:
# 72 mph
# 25 updated to:
# 25 mph
# 25 updated to:
# 25 mph
# 72 updated to:
# 72 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 56 updated to:
# 56 mph
# 72 updated to:
# 72 mph
# 72 updated to:
# 72 mph
# 72 updated to:
# 72 mph
# 89 updated to:
# 89 mph
# 89 updated to:
# 89 mph
# 89 updated to:
# 89 mph
# 89 updated to:
# 89 mph
# 89 updated to:
# 89 mph
# 89 updated to:
# 89 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 72 updated to:
# 72 mph
# 72 updated to:
# 72 mph
# 72 updated to:
# 72 mph
# 72 updated to:
# 72 mph
# 72 updated to:
# 72 mph
# 72 updated to:
# 72 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 89 updated to:
# 89 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 89 updated to:
# 89 mph
# 72 updated to:
# 72 mph
# 56 updated to:
# 56 mph
# 89 updated to:
# 89 mph
# 89 updated to:
# 89 mph
# 72 updated to:
# 72 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 72 updated to:
# 72 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 72 updated to:
# 72 mph
# 72 updated to:
# 72 mph
# 72 updated to:
# 72 mph
# 72 updated to:
# 72 mph
# 72 updated to:
# 72 mph
# 105 updated to:
# 105 mph
# 72 updated to:
# 72 mph
# 72 updated to:
# 72 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 105 updated to:
# 105 mph
# 25 updated to:
# 25 mph

# %% [markdown]
# # Main Function

# %%
import cerberus
import xml.etree.cElementTree as ET
import schema
import csv
import codecs
import pprint
import re
from collections import defaultdict
OSM_PATH = "Columbus.osm"

NODES_PATH = "nodes.csv"
NODE_TAGS_PATH = "nodes_tags.csv"
WAYS_PATH = "ways.csv"
WAY_NODES_PATH = "ways_nodes.csv"
WAY_TAGS_PATH = "ways_tags.csv"

LOWER_COLON = re.compile(r'^([a-z]|_)+:([a-z]|_)+')
PROBLEMCHARS = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

SCHEMA = schema.schema

# Make sure the fields order in the csvs matches the column order in the sql table schema
NODE_FIELDS = ['id', 'lat', 'lon', 'user', 'uid', 'version', 'changeset', 'timestamp']
NODE_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_FIELDS = ['id', 'user', 'uid', 'version', 'changeset', 'timestamp']
WAY_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_NODES_FIELDS = ['id', 'node_id', 'position']

#variables to call in shape_element
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

#mapping to call in shape_element
streetmapping = { "St": "Street",
            "St.": "Street",
            "Ave": "Avenue",
            "Rd.": "Road",
            "Rd": "Road",
            "Blvd": "Boulevard",
            "Dr": "Drive",
            "Dr.": "Drive",
            "S": "South",
            "SE": "Southeast",
            "SW": "Southwest",
            "N": "North",
            "NW": "Northwest",
            "NE": "Northeast",
            "Pkwy": "Parkway",
            "Rd 101": "Road",
            "St Suite 105": "Street",
            "Rd 250": "Road",
            "Rd 2D": "Road",
            "Rd #320": "Road",
            "8877": "Bad Address",
            "8897": " Bad Address"
            }

citymapping = { "Columbus, OH": "Columbus",
                "Dublin, OH": "Dublin",
                "Reynoldsburh": "Reynoldsburg",
                "Pickertington": "Pickerington"
            }

denommapping = { "united_methodist;methodist": "methodist",
                 "united_methodist": "methodist"
            }

sportsmapping = { "multi": "athletics",
                  "beachvolleyball": "volleyball",
                  "football": "american_football",
                  "ice_hockey": "hockey",
                  "karting": "motor",
                  "soccer,_crossfit": "soccer",
            }

cuisinemapping = { "American;Mexican": "mexican",
                   "Vietnamese,_Cambodian": "vietnamese",
                   "bavarian;ice_cream": "ice_cream",
                   "Asian_Fusion": "asian",
                   "Burrito,_Taco, Salad, Chips": "mexican",
                   "Ice_Cream": "ice_cream",
                   "Deli": "sandwich",
                   "Japanese_Sushi_Hibachi": "japanese",
                   "sushi": "japanese",
                   "japanese_steakhouse": "japanese",
                   "Lebanese-American food": "lebanese",
                   "Lebanese_/_Mideastern": "lebanese",
                   "Pasta": "italian",
                   "pasta": "italian",
                   "Steakhouse_chain": "steak",
                   "american_french": "french",
                   "beer;wings": "wings",
                   "bagel": "breakfast",
                   "burger,_shakes": "burger",
                   "chinese;vietnamese": "chinese",
                   "donut": "breakfast",
                   "donuts": "breakfast",
                   "fusion;coffee": "coffee_shop",
                   "home_cooking": "american",
                   "ice_cream,_frozen_yogurt": "ice_cream",
                   "italian._pizza,_bbq,_regional": "italian",
                   "subs": "sandwich"
            }

#Functions to call in shape_element cleaning process
def update_name_street(name, streetmapping):
    if name == "E Dublin Granville Rd #101":
        name = "E Dublin Granville Road"
    elif name == "Mill St Suite 105":
        name = "Mill Street"
    elif name == "Chambers Rd #250":
        name = "Chambers Road"
    elif name == "Copeland Mill Rd #2D":
        name = "Copeland Mill Road"
    elif name == "W Old Wilson Bridge Rd #320":
        name = "W Old Wilson Bridge Road"
    
    else:
        m = street_type_re.search(name)
        street_type = m.group()
        if street_type in streetmapping.keys():
            name = re.sub(m.group(), streetmapping[m.group()],name)
    return name

def update_zips(name):
    if len(name) < 5:
        #print name, 'updated to:'
        name = "Bad Zip"
        #print name
        return name
    elif len(name) > 5:
        #print name, 'updated to:'
        if re.search('[0-9]{5}', name):
            updated_name = re.findall('[0-9]{5}', name)
            name = updated_name[0]
            #print name
            return name
    
    else:
        return name

def update_name_city(name, citymapping):
    if name in citymapping:
        #print name, "updated to:"
        name = citymapping[name]
        if name.islower():
            name = name.capitalize()
        #print name
        return name

    else:
        if name.islower():
            name = name.capitalize()
        return name

def update_name_denom(name, denommapping):
    if name.istitle():
        #print name, 'updated to:'
        name = name.lower()
        #print name
        return name
    elif name in denommapping:
        #print name, "updated to:"
        name = denommapping[name]
        #print name
        return name

    else:
        return name

def first_lower(s):
    return s[0].lower() + s[1:]

def update_name_sport(name, sportsmapping):
    if name in sportsmapping:
        #print name, "updated to:"
        name = sportsmapping[name]
        #print name
        return name

    else:
        return name

def update_name_cuisine(name, cuisinemapping):
    if name in cuisinemapping:
        #print name, 'updated to:'
        name = cuisinemapping[name]
        #print name
        return name

    else:
        return first_lower(name)

def update_name_maxspeed(name):
    if len(name) > 7:
        name = "Bad Speed"
        return name
    if 'mph' in name:
        return name
    else:
        #print name, 'updated to:'
        name = name.strip() + ' mph'
        #print name
        return name

def right_key(k):
    index = k.find(':')
    types = k[:index]
    k = k[index + 1:]
    return k,types

#Main Function
def shape_element(element, node_attr_fields=NODE_FIELDS, way_attr_fields=WAY_FIELDS,
                  problem_chars=PROBLEMCHARS, default_tag_type='regular'):
    """Clean and shape node or way XML element to Python dict"""

    node_atts = {}
    way_atts = {}
    way_nodes = []
    tags = []
    
    if element.tag == 'node': #fill dictionary with k/v pairs from NODE_FIELDS
        for i in node_attr_fields:
            node_atts[i] = element.attrib[i]

    if element.tag == 'way':
        for i in way_attr_fields:
            way_atts[i] = element.attrib[i]

    for tag in element.iter("tag"): #loop through tags looking for problem values
        dic = {}
        attributes = tag.attrib
        if tag.attrib['k'] == "addr:street":
            tag.attrib['v'] = update_name_street(tag.attrib['v'], streetmapping)
        elif tag.attrib['k'] == "addr:city":
            tag.attrib['v'] = update_name_city(tag.attrib['v'], citymapping)
        elif tag.attrib['k'] == "addr:postcode":
            tag.attrib['v'] = update_zips(tag.attrib['v'])
        elif tag.attrib['k'] == "denomination":
            tag.attrib['v'] = update_name_denom(tag.attrib['v'], denommapping)
        elif tag.attrib['k'] == "sport":
            tag.attrib['v'] = update_name_sport(tag.attrib['v'], sportsmapping)
        elif tag.attrib['k'] == "cuisine":
            tag.attrib['v'] = update_name_cuisine(tag.attrib['v'], cuisinemapping)
        elif tag.attrib['k'] == "maxspeed":
            tag.attrib['v'] = update_name_maxspeed(tag.attrib['v'])      
        
        
        if problem_chars.search(tag.attrib['k']):
            continue

        if element.tag == 'node': #add node id for attributes
            dic['id'] = node_atts['id']
        else:
            dic['id'] = way_atts['id'] #add way id for attributes

        dic['value'] = attributes['v'] #value of key for each type

        colon_k=LOWER_COLON.search(tag.attrib['k'])
        
        if colon_k:
            #print colon_k.group(0)
            #print tag.attrib['k']
            dic['key'],dic['type'] = right_key(tag.attrib['k']) #call function to split at colon
        else:
            dic['key'] = attributes['k'] #assign regular that there was no colon problem
            dic['type'] = 'regular'

        tags.append(dic)

    if element.tag == 'way':
        position = 0
        for nd in element.iter("nd"): #loop through nd child tags numbering them
            way_node_dic = {}
            way_node_dic['id'] = way_atts['id']
            way_node_dic['node_id'] = nd.attrib['ref']
            way_node_dic['position'] = position
            position = position + 1
            way_nodes.append(way_node_dic)

    if element.tag == 'node':       #process the above for node tags for final formatting
        return {'node': node_atts, 'node_tags': tags}

    elif element.tag == 'way':      #process the above for way tags for final formatting
        return {'way': way_atts, 'way_nodes': way_nodes, 'way_tags': tags}

# ================================================== #
#               Helper Functions                     #
# ================================================== #

def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag"""

    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


def validate_element(element, validator, schema=SCHEMA):
    """Raise ValidationError if element does not match schema"""
    if validator.validate(element, schema) is not True:
        field, errors = next(validator.errors.iteritems())
        message_string = "\nElement of type '{0}' has the following errors:\n{1}"
        error_string = pprint.pformat(errors)

        raise Exception(message_string.format(field, error_string))


class UnicodeDictWriter(csv.DictWriter, object):
    """Extend csv.DictWriter to handle Unicode input"""

    def writerow(self, row):
        super(UnicodeDictWriter, self).writerow({
            k: (v.encode('utf-8') if isinstance(v, unicode) else v) for k, v in row.iteritems()
        })

    def writerows(self, rows):
        for row in rows:
            self.writerow(row)


# ================================================== #
#               Main Function                        #
# ================================================== #
def process_map(file_in, validate):
    """Iteratively process each XML element and write to csv(s)"""

    with codecs.open(NODES_PATH, 'w') as nodes_file, \
         codecs.open(NODE_TAGS_PATH, 'w') as nodes_tags_file, \
         codecs.open(WAYS_PATH, 'w') as ways_file, \
         codecs.open(WAY_NODES_PATH, 'w') as way_nodes_file, \
         codecs.open(WAY_TAGS_PATH, 'w') as way_tags_file:

        nodes_writer = UnicodeDictWriter(nodes_file, NODE_FIELDS)
        node_tags_writer = UnicodeDictWriter(nodes_tags_file, NODE_TAGS_FIELDS)
        ways_writer = UnicodeDictWriter(ways_file, WAY_FIELDS)
        way_nodes_writer = UnicodeDictWriter(way_nodes_file, WAY_NODES_FIELDS)
        way_tags_writer = UnicodeDictWriter(way_tags_file, WAY_TAGS_FIELDS)

        nodes_writer.writeheader()
        node_tags_writer.writeheader()
        ways_writer.writeheader()
        way_nodes_writer.writeheader()
        way_tags_writer.writeheader()

        validator = cerberus.Validator()

        for element in get_element(file_in, tags=('node', 'way')):
            el = shape_element(element)
            if el:
                if validate is True:
                    validate_element(el, validator)

                if element.tag == 'node':
                    nodes_writer.writerow(el['node'])
                    node_tags_writer.writerows(el['node_tags'])
                elif element.tag == 'way':
                    ways_writer.writerow(el['way'])
                    way_nodes_writer.writerows(el['way_nodes'])
                    way_tags_writer.writerows(el['way_tags'])


if __name__ == '__main__':
    # Note: Validation is ~ 10X slower. For the project consider using a small
    # sample of the map when validating.
    process_map(OSM_PATH, validate=True)

# %% [markdown]
# * Next 5 create tables in database

# %%
import sqlite3
import csv
from pprint import pprint

sqlite_file = 'columbusaudit.db'

conn = sqlite3.connect(sqlite_file)

cur = conn.cursor()

cur.execute('DROP TABLE IF EXISTS nodes')
conn.commit()

cur.execute('''
    CREATE TABLE nodes(id INTEGER PRIMARY KEY NOT NULL,
    lat REAL,
    lon REAL,
    user TEXT,
    uid INTEGER,
    version INTEGER,
    changeset INTEGER,
    timestamp TEXT)
''')
conn.commit()

with open('nodes.csv','rb') as fin:
    dr = csv.DictReader(fin)
    to_db = [(i['id'], i['lat'],i['lon'], i['user'].decode("utf-8"), i['uid'], i['version'], i['changeset'], i['timestamp']) for i in dr]
    
# insert data
cur.executemany("INSERT INTO nodes(id, lat, lon, user, uid, version, changeset, timestamp) VALUES (?, ?, ?, ?, ?, ?, ?, ?);", to_db)
# commit the changes
conn.commit()

#cur.execute('SELECT * FROM nodes')
#all_rows = cur.fetchall()
#print('1):')
#pprint(all_rows)

conn.close()

# %%
sqlite_file = 'columbusaudit.db'

conn = sqlite3.connect(sqlite_file)

cur = conn.cursor()

cur.execute('DROP TABLE IF EXISTS nodes_tags')
conn.commit()

cur.execute('''
    CREATE TABLE nodes_tags (
    id INTEGER,
    key TEXT,
    value TEXT,
    type TEXT,
    FOREIGN KEY (id) REFERENCES nodes(id))
''')
conn.commit()

with open('nodes_tags.csv','rb') as fin:
    dr = csv.DictReader(fin) # comma is default delimiter
    to_db = [(i['id'], i['key'],i['value'].decode("utf-8"), i['type']) for i in dr]
    
# insert data
cur.executemany("INSERT INTO nodes_tags(id, key, value, type) VALUES (?, ?, ?, ?);", to_db)
# commit the changes
conn.commit()

#cur.execute('SELECT * FROM nodes_tags')
#all_rows = cur.fetchall()
#print('1):')
#pprint(all_rows)

conn.close()

# %%
sqlite_file = 'columbusaudit.db'

conn = sqlite3.connect(sqlite_file)

cur = conn.cursor()

cur.execute('DROP TABLE IF EXISTS ways')
conn.commit()

cur.execute('''
    CREATE TABLE ways (
    id INTEGER PRIMARY KEY NOT NULL,
    user TEXT,
    uid INTEGER,
    version TEXT,
    changeset INTEGER,
    timestamp TEXT)
''')
conn.commit()

with open('ways.csv','rb') as fin:
    dr = csv.DictReader(fin) # comma is default delimiter
    to_db = [(i['id'], i['user'].decode("utf-8"), i['uid'], i['version'], i['changeset'], i['timestamp']) for i in dr]
    
# insert data
cur.executemany("INSERT INTO ways(id, user, uid, version, changeset, timestamp) VALUES (?, ?, ?, ?, ?, ?);", to_db)
# commit the changes
conn.commit()

#cur.execute('SELECT * FROM ways')
#all_rows = cur.fetchall()
#print('1):')
#pprint(all_rows)

conn.close()

# %%
sqlite_file = 'columbusaudit.db'

conn = sqlite3.connect(sqlite_file)

cur = conn.cursor()

cur.execute('DROP TABLE IF EXISTS ways_tags')
conn.commit()

cur.execute('''
    CREATE TABLE ways_tags (
    id INTEGER NOT NULL,
    key TEXT NOT NULL,
    value TEXT NOT NULL,
    type TEXT,
    FOREIGN KEY (id) REFERENCES ways(id))
''')
conn.commit()

with open('ways_tags.csv','rb') as fin:
    dr = csv.DictReader(fin) # comma is default delimiter
    to_db = [(i['id'], i['key'],i['value'].decode("utf-8"), i['type']) for i in dr]
    
# insert data
cur.executemany("INSERT INTO ways_tags(id, key, value, type) VALUES (?, ?, ?, ?);", to_db)
# commit the changes
conn.commit()

#cur.execute('SELECT * FROM ways_tags')
#all_rows = cur.fetchall()
#print('1):')
#pprint(all_rows)

conn.close()

# %%
sqlite_file = 'columbusaudit.db'

conn = sqlite3.connect(sqlite_file)

cur = conn.cursor()

cur.execute('DROP TABLE IF EXISTS ways_nodes')
conn.commit()

cur.execute('''
    CREATE TABLE ways_nodes (
    id INTEGER NOT NULL,
    node_id INTEGER NOT NULL,
    position INTEGER NOT NULL,
    FOREIGN KEY (id) REFERENCES ways(id),
    FOREIGN KEY (node_id) REFERENCES nodes(id))
''')
conn.commit()

with open('ways_nodes.csv','rb') as fin:
    dr = csv.DictReader(fin) # comma is default delimiter
    to_db = [(i['id'], i['node_id'],i['position']) for i in dr]
    
# insert data
cur.executemany("INSERT INTO ways_nodes(id, node_id, position) VALUES (?, ?, ?);", to_db)
# commit the changes
conn.commit()

#cur.execute('SELECT * FROM ways_nodes')
#all_rows = cur.fetchall()
#print('1):')
#pprint(all_rows)

conn.close()

# %%
conn = sqlite3.connect(sqlite_file)
cursor = conn.cursor()
cursor.execute('''
    SELECT COUNT(*) FROM nodes;
''')
results = cursor.fetchall()
print results
conn.close
# Out:
# [(675741,)]
# <function close>

# %%
conn = sqlite3.connect(sqlite_file)
cursor = conn.cursor()
cursor.execute('''
    SELECT COUNT(*) FROM ways;
''')
results = cursor.fetchall()
print results
conn.close
# Out:
# [(75957,)]
# <function close>

# %%
conn = sqlite3.connect(sqlite_file)
cursor = conn.cursor()
cursor.execute('''
    SELECT Count(DISTINCT both.user)
    FROM (SELECT user FROM nodes
    UNION ALL SELECT user FROM ways) as both;
''')
results = cursor.fetchall()
print results
conn.close
# Out:
# [(765,)]
# <function close>

# %%
import pandas as pd 

conn = sqlite3.connect(sqlite_file)
cursor = conn.cursor()
cursor.execute('''
    SELECT both.value, COUNT(*) as Total 
    FROM (SELECT * FROM nodes_tags UNION ALL 
    SELECT * FROM ways_tags) as both
    WHERE both.key == 'city'
    GROUP BY both.value
    ORDER BY Total DESC
    LIMIT 10;
''')

results = cursor.fetchall()
df = pd.DataFrame(results)
print df
conn.close
# Out:
#                  0    1
# 0         Columbus  803
# 1           Dublin  329
# 2  Upper Arlington   98
# 3         Hilliard   82
# 4     Pickerington   58
# 5         Galloway   29
# 6     Reynoldsburg   27
# 7        Pataskala   22
# 8       New Albany   21
# 9      Worthington   21
# <function close>

# %%
import pandas as pd 

conn = sqlite3.connect(sqlite_file)
cursor = conn.cursor()
cursor.execute('''
    SELECT both.value, COUNT(*) as Total 
    FROM (SELECT * FROM nodes_tags UNION ALL 
    SELECT * FROM ways_tags) as both
    WHERE both.key == 'postcode'
    GROUP BY both.value
    ORDER BY Total DESC
    LIMIT 5;
''')

results = cursor.fetchall()
df = pd.DataFrame(results)
print df
conn.close
# Out:
#        0    1
# 0  43017  319
# 1  43221  111
# 2  43210   89
# 3  43026   86
# 4  43215   79
# <function close>

# %% [markdown]
# * ElaineNewport put a Marathon gas station in Adamsville, Alabama.  Deemed not significant enough to put in final write-up submission, can easily remove node before reinserting cleaned data to OpenStreetMap.

# %%
conn = sqlite3.connect(sqlite_file)
cursor = conn.cursor()
cursor.execute('''
    SELECT * 
    FROM nodes_tags JOIN nodes
    on nodes_tags.id = nodes.id
    WHERE nodes_tags.key == 'postcode' and nodes_tags.value = 35005;
''')

results = cursor.fetchall()
df = pd.DataFrame(results)
print df
conn.close
# Out:
#            0         1      2     3           4         5          6   \
# 0  1278853280  postcode  35005  addr  1278853280  39.98465 -82.815342
#
#               7        8   9         10                    11
# 0  ElaineNewport  2564091   3  28033823  2015-01-10T05:07:17Z
# <function close>

# %%
conn = sqlite3.connect(sqlite_file)
cursor = conn.cursor()
cursor.execute('''
    SELECT * 
    FROM nodes_tags 
    WHERE id == 1278853280;
''')

results = cursor.fetchall()
df = pd.DataFrame(results)
print df
conn.close
# Out:
#             0              1                           2        3
# 0  1278853280           city                  Adamsville     addr
# 1  1278853280    housenumber                       35005     addr
# 2  1278853280       postcode                       35005     addr
# 3  1278853280          state                     Alabama     addr
# 4  1278853280         street           East Broad Street     addr
# 5  1278853280        amenity                        fuel  regular
# 6  1278853280           name                    Marathon  regular
# 7  1278853280  opening_hours                      sasqsq  regular
# 8  1278853280       operator                 sqsqsqsqsqs  regular
# 9  1278853280      wikipedia  en:1995 World Marathon Cup  regular
# <function close>

# %%
conn = sqlite3.connect(sqlite_file)
cursor = conn.cursor()
cursor.execute('''
    SELECT value, COUNT(*) as Total 
    FROM nodes_tags
    WHERE key == 'denomination'
    GROUP BY value
    ORDER BY Total DESC
    LIMIT 5;
''')

results = cursor.fetchall()
df = pd.DataFrame(results)
print df
conn.close
# Out:
#               0    1
# 0       baptist  127
# 1     methodist   52
# 2      lutheran   38
# 3      catholic   21
# 4  presbyterian   17
# <function close>

# %%
conn = sqlite3.connect(sqlite_file)
cursor = conn.cursor()
cursor.execute('''
    SELECT both.value, COUNT(*) as Total 
    FROM (SELECT * FROM nodes_tags UNION ALL 
    SELECT * FROM ways_tags) as both
    WHERE both.key == 'sport'
    GROUP BY both.value
    ORDER BY Total DESC
    LIMIT 5;
''')

results = cursor.fetchall()
df = pd.DataFrame(results)
print df
conn.close
# Out:
#                    0    1
# 0           baseball  311
# 1             tennis  203
# 2             soccer  100
# 3         basketball   94
# 4  american_football   70
# <function close>

# %%
conn = sqlite3.connect(sqlite_file)
cursor = conn.cursor()
cursor.execute('''
    SELECT both.value, COUNT(*) as Total 
    FROM (SELECT * FROM nodes_tags UNION ALL 
    SELECT * FROM ways_tags)
    as both
    WHERE both.key == 'cuisine'
    GROUP BY both.value
    ORDER BY Total DESC
    LIMIT 5;
''')

results = cursor.fetchall()
df = pd.DataFrame(results)
print df
conn.close
# Out:
#           0   1
# 0    burger  77
# 1   mexican  56
# 2     pizza  48
# 3  sandwich  38
# 4  american  32
# <function close>

# %%
conn = sqlite3.connect(sqlite_file)
cursor = conn.cursor()

cursor.execute('''
    CREATE view both as
    SELECT * FROM nodes_tags UNION ALL 
    SELECT * FROM ways_tags;
''')

# %%
cursor.execute('''
    CREATE view coffee_shop as
    SELECT id
    FROM both
    WHERE both.key == 'cuisine' and both.value == 'coffee_shop';
''')

# %%
cursor.execute('''
    SELECT both.value, COUNT(*) from both
    JOIN coffee_shop
    on both.id = coffee_shop.id
    WHERE both.key = 'name' and both.value = 'Starbucks'
''')

results = cursor.fetchall()
df = pd.DataFrame(results)
print df
conn.close
# Out:
#            0   1
# 0  Starbucks  11
# <function close>

# %%
conn = sqlite3.connect(sqlite_file)
cursor = conn.cursor()
cursor.execute('''
    SELECT both.value, Count(*)   
    FROM (SELECT * FROM nodes_tags UNION ALL 
    SELECT * FROM ways_tags) as both
    WHERE both.value == 'Starbucks';
''')

results = cursor.fetchall()
print results
conn.close
# Out:
# [(u'Starbucks', 23)]
# <function close>

# %%
conn = sqlite3.connect(sqlite_file)
cursor = conn.cursor()
cursor.execute('''
    SELECT both.value, COUNT(*) as Total 
    FROM (SELECT * FROM nodes_tags UNION ALL 
    SELECT * FROM ways_tags)
    as both
    WHERE both.key == 'maxspeed'
    GROUP BY both.value
    ORDER BY Total DESC
    Limit 6;
''')

results = cursor.fetchall()
df = pd.DataFrame(results)
print df
conn.close
# Out:
#          0    1
# 0   65 mph  641
# 1   55 mph  321
# 2   25 mph  249
# 3   35 mph  180
# 4   45 mph  168
# 5  105 mph   74
# <function close>

# %%
#use both view as a table to join
conn = sqlite3.connect(sqlite_file)
cursor = conn.cursor()
cursor.execute('''
    SELECT ways.user, COUNT(*) as Total 
    FROM both JOIN ways
    on both.id = ways.id
    WHERE both.key = 'maxspeed' and both.value = '105 mph'
    GROUP BY ways.user
    ORDER BY Total DESC;
''')

results = cursor.fetchall()
df = pd.DataFrame(results)
print df
conn.close
# Out:
#               0   1
# 0   Vid the Kid  37
# 1           NE2  32
# 2          cl94   3
# 3  Sunfishtommy   2
# <function close>
